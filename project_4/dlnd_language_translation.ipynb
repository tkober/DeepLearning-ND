# %% [markdown]
# # Language Translation
# In this project, you’re going to take a peek into the realm of neural network machine translation.  You’ll be training a sequence to sequence model on a dataset of English and French sentences that can translate new sentences from English to French.
# ## Get the Data
# Since translating the whole language of English to French will take lots of time to train, we have provided you with a small portion of the English corpus.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import helper
import problem_unittests as tests

source_path = 'data/small_vocab_en'
target_path = 'data/small_vocab_fr'
source_text = helper.load_data(source_path)
target_text = helper.load_data(target_path)

# %% [markdown]
# ## Explore the Data
# Play around with view_sentence_range to view different parts of the data.

# %%
view_sentence_range = (200, 205)

"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import numpy as np

print('Dataset Stats')
print('Roughly the number of unique words: {}'.format(len({word: None for word in source_text.split()})))

sentences = source_text.split('\n')
word_counts = [len(sentence.split()) for sentence in sentences]
print('Number of sentences: {}'.format(len(sentences)))
print('Average number of words in a sentence: {}'.format(np.average(word_counts)))

print()
print('English sentences {} to {}:'.format(*view_sentence_range))
print('\n'.join(source_text.split('\n')[view_sentence_range[0]:view_sentence_range[1]]))
print()
print('French sentences {} to {}:'.format(*view_sentence_range))
print('\n'.join(target_text.split('\n')[view_sentence_range[0]:view_sentence_range[1]]))
# Out:
# Dataset Stats
# Roughly the number of unique words: 227
# Number of sentences: 137861
# Average number of words in a sentence: 13.225277634719028
#
# English sentences 200 to 205:
# paris is hot during spring , but it is usually snowy in june .
# the grape is your least favorite fruit , but the banana is his least favorite .
# china is never warm during summer , but it is usually quiet in november .
# she dislikes strawberries , pears , and limes .
# his least favorite animal is the mouse .
#
# French sentences 200 to 205:
# paris est chaud au printemps , mais il est généralement enneigée en juin .
# le raisin est votre fruit préféré moins , mais la banane est son moins préféré.
# chine est jamais chaud pendant l' été , mais il est généralement calme en novembre .
# elle n'aime les fraises , les poires et citrons verts .
# son moins animal préféré est la souris .

# %% [markdown]
# ## Implement Preprocessing Function
# ### Text to Word Ids
# As you did with other RNNs, you must turn the text into a number so the computer can understand it. In the function `text_to_ids()`, you'll turn `source_text` and `target_text` from words to ids.  However, you need to add the `<EOS>` word id at the end of each sentence from `target_text`.  This will help the neural network predict when the sentence should end.
#
# You can get the `<EOS>` word id by doing:
# ```python
# target_vocab_to_int['<EOS>']
# ```
# You can get other word ids using `source_vocab_to_int` and `target_vocab_to_int`.

# %%
def text_to_ids(source_text, target_text, source_vocab_to_int, target_vocab_to_int):
    """
    Convert source and target text to proper word ids
    :param source_text: String that contains all the source text.
    :param target_text: String that contains all the target text.
    :param source_vocab_to_int: Dictionary to go from the source words to an id
    :param target_vocab_to_int: Dictionary to go from the target words to an id
    :return: A tuple of lists (source_id_text, target_id_text)
    """
    
    source_sentences = source_text.split('\n')
    target_sentences = target_text.split('\n')
    
    for i in range(len(source_sentences)):
        source_tokens = source_sentences[i].split()
        source_ids = [ source_vocab_to_int[token] for token in source_tokens ]
        source_sentences[i] = source_ids
    
        target_tokens = target_sentences[i].split()
        target_ids = [ target_vocab_to_int[token] for token in target_tokens ]
        target_ids.append( target_vocab_to_int['<EOS>'])
        target_sentences[i] = target_ids
    
    return source_sentences, target_sentences

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_text_to_ids(text_to_ids)
# Out:
# Tests Passed

# %% [markdown]
# ### Preprocess all the data and save it
# Running the code cell below will preprocess all the data and save it to file.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
helper.preprocess_and_save_data(source_path, target_path, text_to_ids)

# %% [markdown]
# # Check Point
# This is your first checkpoint. If you ever decide to come back to this notebook or have to restart the notebook, you can start from here. The preprocessed data has been saved to disk.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import numpy as np
import helper

(source_int_text, target_int_text), (source_vocab_to_int, target_vocab_to_int), _ = helper.load_preprocess()

# %% [markdown]
# ### Check the Version of TensorFlow and Access to GPU
# This will check to make sure you have the correct version of TensorFlow and access to a GPU

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
from distutils.version import LooseVersion
import warnings
import tensorflow as tf

# Check TensorFlow Version
assert LooseVersion(tf.__version__) in [LooseVersion('1.0.0'), LooseVersion('1.0.1')], 'This project requires TensorFlow version 1.0  You are using {}'.format(tf.__version__)
print('TensorFlow Version: {}'.format(tf.__version__))

# Check for a GPU
if not tf.test.gpu_device_name():
    warnings.warn('No GPU found. Please use a GPU to train your neural network.')
else:
    print('Default GPU Device: {}'.format(tf.test.gpu_device_name()))
# Out:
# TensorFlow Version: 1.0.1
# Default GPU Device: /gpu:0

# %% [markdown]
# ## Build the Neural Network
# You'll build the components necessary to build a Sequence-to-Sequence model by implementing the following functions below:
# - `model_inputs`
# - `process_decoding_input`
# - `encoding_layer`
# - `decoding_layer_train`
# - `decoding_layer_infer`
# - `decoding_layer`
# - `seq2seq_model`
#
# ### Input
# Implement the `model_inputs()` function to create TF Placeholders for the Neural Network. It should create the following placeholders:
#
# - Input text placeholder named "input" using the TF Placeholder name parameter with rank 2.
# - Targets placeholder with rank 2.
# - Learning rate placeholder with rank 0.
# - Keep probability placeholder named "keep_prob" using the TF Placeholder name parameter with rank 0.
#
# Return the placeholders in the following the tuple (Input, Targets, Learing Rate, Keep Probability)

# %%
def model_inputs():
    """
    Create TF Placeholders for input, targets, and learning rate.
    :return: Tuple (input, targets, learning rate, keep probability)
    """
    
    inputs = tf.placeholder(tf.int32, shape=[None, None], name='input')
    targets = tf.placeholder(tf.int32, shape=[None, None])
    learning_rate = tf.placeholder(tf.float32)
    keep_probability = tf.placeholder(tf.float32, name='keep_prob')
    
    return inputs, targets, learning_rate, keep_probability

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_model_inputs(model_inputs)
# Out:
# Tests Passed

# %% [markdown]
# ### Process Decoding Input
# Implement `process_decoding_input` using TensorFlow to remove the last word id from each batch in `target_data` and concat the GO ID to the beginning of each batch.

# %%
def process_decoding_input(target_data, target_vocab_to_int, batch_size):
    """
    Preprocess target data for dencoding
    :param target_data: Target Placehoder
    :param target_vocab_to_int: Dictionary to go from the target words to an id
    :param batch_size: Batch Size
    :return: Preprocessed target data
    """
    
    ending = tf.strided_slice(target_data, [0, 0], [batch_size, -1], [1, 1])
    result = tf.concat([tf.fill([batch_size, 1], target_vocab_to_int['<GO>']), ending], 1)
    
    return result
    

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_process_decoding_input(process_decoding_input)
# Out:
# Tests Passed

# %% [markdown]
# ### Encoding
# Implement `encoding_layer()` to create a Encoder RNN layer using [`tf.nn.dynamic_rnn()`](https://www.tensorflow.org/api_docs/python/tf/nn/dynamic_rnn).

# %%
def encoding_layer(rnn_inputs, rnn_size, num_layers, keep_prob):
    """
    Create encoding layer
    :param rnn_inputs: Inputs for the RNN
    :param rnn_size: RNN Size
    :param num_layers: Number of layers
    :param keep_prob: Dropout keep probability
    :return: RNN state
    """
    
    lstm = tf.contrib.rnn.BasicLSTMCell(rnn_size)
    lstm = tf.contrib.rnn.DropoutWrapper(lstm, output_keep_prob=keep_prob)
    lstm = tf.contrib.rnn.MultiRNNCell([lstm] * num_layers)
    output, state = tf.nn.dynamic_rnn(lstm, rnn_inputs, dtype=tf.float32)
    
    return state

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_encoding_layer(encoding_layer)
# Out:
# Tests Passed

# %% [markdown]
# ### Decoding - Training
# Create training logits using [`tf.contrib.seq2seq.simple_decoder_fn_train()`](https://www.tensorflow.org/versions/r1.0/api_docs/python/tf/contrib/seq2seq/simple_decoder_fn_train) and [`tf.contrib.seq2seq.dynamic_rnn_decoder()`](https://www.tensorflow.org/versions/r1.0/api_docs/python/tf/contrib/seq2seq/dynamic_rnn_decoder).  Apply the `output_fn` to the [`tf.contrib.seq2seq.dynamic_rnn_decoder()`](https://www.tensorflow.org/versions/r1.0/api_docs/python/tf/contrib/seq2seq/dynamic_rnn_decoder) outputs.

# %%
def decoding_layer_train(encoder_state, dec_cell, dec_embed_input, sequence_length, decoding_scope,
                         output_fn, keep_prob):
    """
    Create a decoding layer for training
    :param encoder_state: Encoder State
    :param dec_cell: Decoder RNN Cell
    :param dec_embed_input: Decoder embedded input
    :param sequence_length: Sequence Length
    :param decoding_scope: TenorFlow Variable Scope for decoding
    :param output_fn: Function to apply the output layer
    :param keep_prob: Dropout keep probability
    :return: Train Logits
    """
    
    decoder_fn_train = tf.contrib.seq2seq.simple_decoder_fn_train(encoder_state)
    dropout = tf.contrib.rnn.DropoutWrapper(dec_cell, output_keep_prob=keep_prob)
    outputs, _, _ = tf.contrib.seq2seq.dynamic_rnn_decoder(dropout,
                                                           decoder_fn_train,
                                                           dec_embed_input,
                                                           sequence_length,
                                                           scope=decoding_scope)
    
    return output_fn(outputs)


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_decoding_layer_train(decoding_layer_train)
# Out:
# Tests Passed

# %% [markdown]
# ### Decoding - Inference
# Create inference logits using [`tf.contrib.seq2seq.simple_decoder_fn_inference()`](https://www.tensorflow.org/versions/r1.0/api_docs/python/tf/contrib/seq2seq/simple_decoder_fn_inference) and [`tf.contrib.seq2seq.dynamic_rnn_decoder()`](https://www.tensorflow.org/versions/r1.0/api_docs/python/tf/contrib/seq2seq/dynamic_rnn_decoder).

# %%
def decoding_layer_infer(encoder_state, dec_cell, dec_embeddings, start_of_sequence_id, end_of_sequence_id,
                         maximum_length, vocab_size, decoding_scope, output_fn, keep_prob):
    """
    Create a decoding layer for inference
    :param encoder_state: Encoder state
    :param dec_cell: Decoder RNN Cell
    :param dec_embeddings: Decoder embeddings
    :param start_of_sequence_id: GO ID
    :param end_of_sequence_id: EOS Id
    :param maximum_length: The maximum allowed time steps to decode
    :param vocab_size: Size of vocabulary
    :param decoding_scope: TensorFlow Variable Scope for decoding
    :param output_fn: Function to apply the output layer
    :param keep_prob: Dropout keep probability
    :return: Inference Logits
    """

    decoder_fn = tf.contrib.seq2seq.simple_decoder_fn_inference(output_fn, 
                                                                encoder_state, 
                                                                dec_embeddings,
                                                                start_of_sequence_id, 
                                                                end_of_sequence_id,
                                                                maximum_length, 
                                                                vocab_size,
                                                                dtype=tf.int32)
    logits, _, _  = tf.contrib.seq2seq.dynamic_rnn_decoder(dec_cell, decoder_fn, scope=decoding_scope)
    
    return logits


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_decoding_layer_infer(decoding_layer_infer)
# Out:
# Tests Passed

# %% [markdown]
# ### Build the Decoding Layer
# Implement `decoding_layer()` to create a Decoder RNN layer.
#
# - Create RNN cell for decoding using `rnn_size` and `num_layers`.
# - Create the output fuction using [`lambda`](https://docs.python.org/3/tutorial/controlflow.html#lambda-expressions) to transform it's input, logits, to class logits.
# - Use the your `decoding_layer_train(encoder_state, dec_cell, dec_embed_input, sequence_length, decoding_scope, output_fn, keep_prob)` function to get the training logits.
# - Use your `decoding_layer_infer(encoder_state, dec_cell, dec_embeddings, start_of_sequence_id, end_of_sequence_id, maximum_length, vocab_size, decoding_scope, output_fn, keep_prob)` function to get the inference logits.
#
# Note: You'll need to use [tf.variable_scope](https://www.tensorflow.org/api_docs/python/tf/variable_scope) to share variables between training and inference.

# %%
def decoding_layer(dec_embed_input, dec_embeddings, encoder_state, vocab_size, sequence_length, rnn_size,
                   num_layers, target_vocab_to_int, keep_prob):
    """
    Create decoding layer
    :param dec_embed_input: Decoder embedded input
    :param dec_embeddings: Decoder embeddings
    :param encoder_state: The encoded state
    :param vocab_size: Size of vocabulary
    :param sequence_length: Sequence Length
    :param rnn_size: RNN Size
    :param num_layers: Number of layers
    :param target_vocab_to_int: Dictionary to go from the target words to an id
    :param keep_prob: Dropout keep probability
    :return: Tuple of (Training Logits, Inference Logits)
    """
    
    
    
    sequence_start_id = target_vocab_to_int['<GO>']
    sequence_end_id = target_vocab_to_int['<EOS>']

    lstm = tf.contrib.rnn.BasicLSTMCell(rnn_size)
    #lstm = tf.contrib.rnn.DropoutWrapper(lstm, output_keep_prob=keep_prob)
    lstm = tf.contrib.rnn.MultiRNNCell([lstm] * num_layers)
     
    with tf.variable_scope('decoding') as decoding_scope:
        
        output_fn = lambda x: tf.contrib.layers.fully_connected(x, vocab_size, None, scope=decoding_scope)
        training_logits = decoding_layer_train(encoder_state, 
                                               lstm, 
                                               dec_embed_input, 
                                               sequence_length,
                                               decoding_scope, 
                                               output_fn, 
                                               keep_prob)
        decoding_scope.reuse_variables()        
        inference_logits = decoding_layer_infer(encoder_state, 
                                                lstm, 
                                                dec_embeddings, 
                                                sequence_start_id,
                                                sequence_end_id, 
                                                sequence_length, 
                                                vocab_size, 
                                                decoding_scope,
                                                output_fn, 
                                                keep_prob)
 
    return training_logits, inference_logits


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_decoding_layer(decoding_layer)
# Out:
# Tests Passed

# %% [markdown]
# ### Build the Neural Network
# Apply the functions you implemented above to:
#
# - Apply embedding to the input data for the encoder.
# - Encode the input using your `encoding_layer(rnn_inputs, rnn_size, num_layers, keep_prob)`.
# - Process target data using your `process_decoding_input(target_data, target_vocab_to_int, batch_size)` function.
# - Apply embedding to the target data for the decoder.
# - Decode the encoded input using your `decoding_layer(dec_embed_input, dec_embeddings, encoder_state, vocab_size, sequence_length, rnn_size, num_layers, target_vocab_to_int, keep_prob)`.

# %%
def seq2seq_model(input_data, target_data, keep_prob, batch_size, sequence_length, source_vocab_size, target_vocab_size,
                  enc_embedding_size, dec_embedding_size, rnn_size, num_layers, target_vocab_to_int):
    """
    Build the Sequence-to-Sequence part of the neural network
    :param input_data: Input placeholder
    :param target_data: Target placeholder
    :param keep_prob: Dropout keep probability placeholder
    :param batch_size: Batch Size
    :param sequence_length: Sequence Length
    :param source_vocab_size: Source vocabulary size
    :param target_vocab_size: Target vocabulary size
    :param enc_embedding_size: Decoder embedding size
    :param dec_embedding_size: Encoder embedding size
    :param rnn_size: RNN Size
    :param num_layers: Number of layers
    :param target_vocab_to_int: Dictionary to go from the target words to an id
    :return: Tuple of (Training Logits, Inference Logits)
    """
    
    input_embeddings = tf.contrib.layers.embed_sequence(input_data, source_vocab_size, enc_embedding_size)
    encoder_state = encoding_layer(input_embeddings, rnn_size, num_layers, keep_prob)
    
    processed_targets = process_decoding_input(target_data, target_vocab_to_int, batch_size)
    
    decoder_embeddings = tf.Variable(tf.random_uniform([target_vocab_size, dec_embedding_size]))
    decoder_embedding_input = tf.nn.embedding_lookup(decoder_embeddings, processed_targets) 

    train_logits, inference_logits = decoding_layer(decoder_embedding_input, 
                                                    decoder_embeddings, 
                                                    encoder_state, 
                                                    target_vocab_size, 
                                                    sequence_length, 
                                                    rnn_size, 
                                                    num_layers, 
                                                    target_vocab_to_int, 
                                                    keep_prob)
    
    return train_logits, inference_logits


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_seq2seq_model(seq2seq_model)
# Out:
# Tests Passed

# %% [markdown]
# ## Neural Network Training
# ### Hyperparameters
# Tune the following parameters:
#
# - Set `epochs` to the number of epochs.
# - Set `batch_size` to the batch size.
# - Set `rnn_size` to the size of the RNNs.
# - Set `num_layers` to the number of layers.
# - Set `encoding_embedding_size` to the size of the embedding for the encoder.
# - Set `decoding_embedding_size` to the size of the embedding for the decoder.
# - Set `learning_rate` to the learning rate.
# - Set `keep_probability` to the Dropout keep probability

# %%
# Number of Epochs
epochs = 20
# Batch Size
batch_size = 1024
# RNN Size
rnn_size = 256
# Number of Layers
num_layers = 2
# Embedding Size
encoding_embedding_size = 300
decoding_embedding_size = 300
# Learning Rate
learning_rate = 0.001
# Dropout Keep Probability
keep_probability = 0.5

# %% [markdown]
# ### Build the Graph
# Build the graph using the neural network you implemented.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
save_path = 'checkpoints/dev'
(source_int_text, target_int_text), (source_vocab_to_int, target_vocab_to_int), _ = helper.load_preprocess()
max_source_sentence_length = max([len(sentence) for sentence in source_int_text])

train_graph = tf.Graph()
with train_graph.as_default():
    input_data, targets, lr, keep_prob = model_inputs()
    sequence_length = tf.placeholder_with_default(max_source_sentence_length, None, name='sequence_length')
    input_shape = tf.shape(input_data)
    
    train_logits, inference_logits = seq2seq_model(
        tf.reverse(input_data, [-1]), targets, keep_prob, batch_size, sequence_length, len(source_vocab_to_int), len(target_vocab_to_int),
        encoding_embedding_size, decoding_embedding_size, rnn_size, num_layers, target_vocab_to_int)

    tf.identity(inference_logits, 'logits')
    with tf.name_scope("optimization"):
        # Loss function
        cost = tf.contrib.seq2seq.sequence_loss(
            train_logits,
            targets,
            tf.ones([input_shape[0], sequence_length]))

        # Optimizer
        optimizer = tf.train.AdamOptimizer(lr)

        # Gradient Clipping
        gradients = optimizer.compute_gradients(cost)
        capped_gradients = [(tf.clip_by_value(grad, -1., 1.), var) for grad, var in gradients if grad is not None]
        train_op = optimizer.apply_gradients(capped_gradients)

# %% [markdown]
# ### Train
# Train the neural network on the preprocessed data. If you have a hard time getting a good loss, check the forms to see if anyone is having the same problem.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import time

def get_accuracy(target, logits):
    """
    Calculate accuracy
    """
    max_seq = max(target.shape[1], logits.shape[1])
    if max_seq - target.shape[1]:
        target = np.pad(
            target,
            [(0,0),(0,max_seq - target.shape[1])],
            'constant')
    if max_seq - logits.shape[1]:
        logits = np.pad(
            logits,
            [(0,0),(0,max_seq - logits.shape[1]), (0,0)],
            'constant')

    return np.mean(np.equal(target, np.argmax(logits, 2)))

train_source = source_int_text[batch_size:]
train_target = target_int_text[batch_size:]

valid_source = helper.pad_sentence_batch(source_int_text[:batch_size])
valid_target = helper.pad_sentence_batch(target_int_text[:batch_size])

with tf.Session(graph=train_graph) as sess:
    sess.run(tf.global_variables_initializer())

    for epoch_i in range(epochs):
        for batch_i, (source_batch, target_batch) in enumerate(
                helper.batch_data(train_source, train_target, batch_size)):
            start_time = time.time()
            
            _, loss = sess.run(
                [train_op, cost],
                {input_data: source_batch,
                 targets: target_batch,
                 lr: learning_rate,
                 sequence_length: target_batch.shape[1],
                 keep_prob: keep_probability})
            
            batch_train_logits = sess.run(
                inference_logits,
                {input_data: source_batch, keep_prob: 1.0})
            batch_valid_logits = sess.run(
                inference_logits,
                {input_data: valid_source, keep_prob: 1.0})
                
            train_acc = get_accuracy(target_batch, batch_train_logits)
            valid_acc = get_accuracy(np.array(valid_target), batch_valid_logits)
            end_time = time.time()
            print('Epoch {:>3} Batch {:>4}/{} - Train Accuracy: {:>6.3f}, Validation Accuracy: {:>6.3f}, Loss: {:>6.3f}'
                  .format(epoch_i, batch_i, len(source_int_text) // batch_size, train_acc, valid_acc, loss))

    # Save Model
    saver = tf.train.Saver()
    saver.save(sess, save_path)
    print('Model Trained and Saved')
# Out:
# Epoch   0 Batch    0/134 - Train Accuracy:  0.267, Validation Accuracy:  0.310, Loss:  5.925
# Epoch   0 Batch    1/134 - Train Accuracy:  0.238, Validation Accuracy:  0.310, Loss:  5.505
# Epoch   0 Batch    2/134 - Train Accuracy:  0.274, Validation Accuracy:  0.310, Loss:  5.001
# Epoch   0 Batch    3/134 - Train Accuracy:  0.277, Validation Accuracy:  0.310, Loss:  4.606
# Epoch   0 Batch    4/134 - Train Accuracy:  0.270, Validation Accuracy:  0.311, Loss:  4.497
# Epoch   0 Batch    5/134 - Train Accuracy:  0.292, Validation Accuracy:  0.325, Loss:  4.365
# Epoch   0 Batch    6/134 - Train Accuracy:  0.339, Validation Accuracy:  0.341, Loss:  4.006
# Epoch   0 Batch    7/134 - Train Accuracy:  0.304, Validation Accuracy:  0.343, Loss:  4.012
# Epoch   0 Batch    8/134 - Train Accuracy:  0.304, Validation Accuracy:  0.343, Loss:  3.925
# Epoch   0 Batch    9/134 - Train Accuracy:  0.341, Validation Accuracy:  0.343, Loss:  3.661
# Epoch   0 Batch   10/134 - Train Accuracy:  0.313, Validation Accuracy:  0.343, Loss:  3.642
# Epoch   0 Batch   11/134 - Train Accuracy:  0.317, Validation Accuracy:  0.343, Loss:  3.549
# Epoch   0 Batch   12/134 - Train Accuracy:  0.344, Validation Accuracy:  0.343, Loss:  3.346
# Epoch   0 Batch   13/134 - Train Accuracy:  0.332, Validation Accuracy:  0.371, Loss:  3.439
# Epoch   0 Batch   14/134 - Train Accuracy:  0.339, Validation Accuracy:  0.376, Loss:  3.388
# Epoch   0 Batch   15/134 - Train Accuracy:  0.346, Validation Accuracy:  0.380, Loss:  3.334
# Epoch   0 Batch   16/134 - Train Accuracy:  0.348, Validation Accuracy:  0.379, Loss:  3.240
# Epoch   0 Batch   17/134 - Train Accuracy:  0.349, Validation Accuracy:  0.380, Loss:  3.211
# Epoch   0 Batch   18/134 - Train Accuracy:  0.350, Validation Accuracy:  0.381, Loss:  3.175
# Epoch   0 Batch   19/134 - Train Accuracy:  0.349, Validation Accuracy:  0.383, Loss:  3.130
# Epoch   0 Batch   20/134 - Train Accuracy:  0.388, Validation Accuracy:  0.392, Loss:  2.962
# Epoch   0 Batch   21/134 - Train Accuracy:  0.375, Validation Accuracy:  0.400, Loss:  3.036
# Epoch   0 Batch   22/134 - Train Accuracy:  0.335, Validation Accuracy:  0.399, Loss:  3.187
# Epoch   0 Batch   23/134 - Train Accuracy:  0.404, Validation Accuracy:  0.405, Loss:  2.905
# Epoch   0 Batch   24/134 - Train Accuracy:  0.346, Validation Accuracy:  0.404, Loss:  3.093
# Epoch   0 Batch   25/134 - Train Accuracy:  0.378, Validation Accuracy:  0.411, Loss:  3.001
# Epoch   0 Batch   26/134 - Train Accuracy:  0.360, Validation Accuracy:  0.415, Loss:  3.053
# Epoch   0 Batch   27/134 - Train Accuracy:  0.391, Validation Accuracy:  0.421, Loss:  2.936
# Epoch   0 Batch   28/134 - Train Accuracy:  0.377, Validation Accuracy:  0.406, Loss:  2.873
# Epoch   0 Batch   29/134 - Train Accuracy:  0.411, Validation Accuracy:  0.420, Loss:  2.780
# Epoch   0 Batch   30/134 - Train Accuracy:  0.418, Validation Accuracy:  0.421, Loss:  2.714
# Epoch   0 Batch   31/134 - Train Accuracy:  0.393, Validation Accuracy:  0.426, Loss:  2.850
# Epoch   0 Batch   32/134 - Train Accuracy:  0.415, Validation Accuracy:  0.419, Loss:  2.686
# Epoch   0 Batch   33/134 - Train Accuracy:  0.404, Validation Accuracy:  0.435, Loss:  2.810
# Epoch   0 Batch   34/134 - Train Accuracy:  0.413, Validation Accuracy:  0.440, Loss:  2.769
# Epoch   0 Batch   35/134 - Train Accuracy:  0.440, Validation Accuracy:  0.444, Loss:  2.651
# Epoch   0 Batch   36/134 - Train Accuracy:  0.412, Validation Accuracy:  0.438, Loss:  2.714
# Epoch   0 Batch   37/134 - Train Accuracy:  0.411, Validation Accuracy:  0.444, Loss:  2.739
# Epoch   0 Batch   38/134 - Train Accuracy:  0.422, Validation Accuracy:  0.447, Loss:  2.697
# Epoch   0 Batch   39/134 - Train Accuracy:  0.422, Validation Accuracy:  0.451, Loss:  2.660
# Epoch   0 Batch   40/134 - Train Accuracy:  0.435, Validation Accuracy:  0.458, Loss:  2.640
# Epoch   0 Batch   41/134 - Train Accuracy:  0.436, Validation Accuracy:  0.463, Loss:  2.617
# Epoch   0 Batch   42/134 - Train Accuracy:  0.424, Validation Accuracy:  0.455, Loss:  2.643
# Epoch   0 Batch   43/134 - Train Accuracy:  0.437, Validation Accuracy:  0.466, Loss:  2.629
# Epoch   0 Batch   44/134 - Train Accuracy:  0.440, Validation Accuracy:  0.470, Loss:  2.592
# Epoch   0 Batch   45/134 - Train Accuracy:  0.438, Validation Accuracy:  0.470, Loss:  2.581
# Epoch   0 Batch   46/134 - Train Accuracy:  0.469, Validation Accuracy:  0.471, Loss:  2.460
# Epoch   0 Batch   47/134 - Train Accuracy:  0.443, Validation Accuracy:  0.472, Loss:  2.539
# Epoch   0 Batch   48/134 - Train Accuracy:  0.461, Validation Accuracy:  0.481, Loss:  2.515
# Epoch   0 Batch   49/134 - Train Accuracy:  0.460, Validation Accuracy:  0.480, Loss:  2.485
# Epoch   0 Batch   50/134 - Train Accuracy:  0.456, Validation Accuracy:  0.485, Loss:  2.492
# Epoch   0 Batch   51/134 - Train Accuracy:  0.451, Validation Accuracy:  0.479, Loss:  2.481
# Epoch   0 Batch   52/134 - Train Accuracy:  0.454, Validation Accuracy:  0.488, Loss:  2.485
# Epoch   0 Batch   53/134 - Train Accuracy:  0.449, Validation Accuracy:  0.489, Loss:  2.468
# Epoch   0 Batch   54/134 - Train Accuracy:  0.446, Validation Accuracy:  0.476, Loss:  2.437
# Epoch   0 Batch   55/134 - Train Accuracy:  0.440, Validation Accuracy:  0.472, Loss:  2.443
# Epoch   0 Batch   56/134 - Train Accuracy:  0.470, Validation Accuracy:  0.474, Loss:  2.326
# Epoch   0 Batch   57/134 - Train Accuracy:  0.461, Validation Accuracy:  0.487, Loss:  2.412
# Epoch   0 Batch   58/134 - Train Accuracy:  0.464, Validation Accuracy:  0.488, Loss:  2.347
# Epoch   0 Batch   59/134 - Train Accuracy:  0.424, Validation Accuracy:  0.474, Loss:  2.474
# Epoch   0 Batch   60/134 - Train Accuracy:  0.472, Validation Accuracy:  0.495, Loss:  2.359
# Epoch   0 Batch   61/134 - Train Accuracy:  0.471, Validation Accuracy:  0.502, Loss:  2.341
# Epoch   0 Batch   62/134 - Train Accuracy:  0.457, Validation Accuracy:  0.482, Loss:  2.300
# Epoch   0 Batch   63/134 - Train Accuracy:  0.476, Validation Accuracy:  0.497, Loss:  2.314
# Epoch   0 Batch   64/134 - Train Accuracy:  0.467, Validation Accuracy:  0.499, Loss:  2.330
# Epoch   0 Batch   65/134 - Train Accuracy:  0.466, Validation Accuracy:  0.495, Loss:  2.278
# Epoch   0 Batch   66/134 - Train Accuracy:  0.469, Validation Accuracy:  0.500, Loss:  2.255
# Epoch   0 Batch   67/134 - Train Accuracy:  0.441, Validation Accuracy:  0.500, Loss:  2.393
# Epoch   0 Batch   68/134 - Train Accuracy:  0.456, Validation Accuracy:  0.500, Loss:  2.322
# Epoch   0 Batch   69/134 - Train Accuracy:  0.480, Validation Accuracy:  0.500, Loss:  2.199
# Epoch   0 Batch   70/134 - Train Accuracy:  0.487, Validation Accuracy:  0.503, Loss:  2.175
# Epoch   0 Batch   71/134 - Train Accuracy:  0.435, Validation Accuracy:  0.468, Loss:  2.199
# Epoch   0 Batch   72/134 - Train Accuracy:  0.430, Validation Accuracy:  0.459, Loss:  2.228
# Epoch   0 Batch   73/134 - Train Accuracy:  0.440, Validation Accuracy:  0.455, Loss:  2.260
# Epoch   0 Batch   74/134 - Train Accuracy:  0.444, Validation Accuracy:  0.472, Loss:  2.241
# Epoch   0 Batch   75/134 - Train Accuracy:  0.468, Validation Accuracy:  0.471, Loss:  2.107
# Epoch   0 Batch   76/134 - Train Accuracy:  0.466, Validation Accuracy:  0.497, Loss:  2.243
# Epoch   0 Batch   77/134 - Train Accuracy:  0.465, Validation Accuracy:  0.463, Loss:  2.022
# Epoch   0 Batch   78/134 - Train Accuracy:  0.450, Validation Accuracy:  0.481, Loss:  2.171
# Epoch   0 Batch   79/134 - Train Accuracy:  0.466, Validation Accuracy:  0.493, Loss:  2.151
# Epoch   0 Batch   80/134 - Train Accuracy:  0.469, Validation Accuracy:  0.498, Loss:  2.148
# Epoch   0 Batch   81/134 - Train Accuracy:  0.456, Validation Accuracy:  0.485, Loss:  2.119
# Epoch   0 Batch   82/134 - Train Accuracy:  0.468, Validation Accuracy:  0.473, Loss:  1.973
# Epoch   0 Batch   83/134 - Train Accuracy:  0.471, Validation Accuracy:  0.497, Loss:  2.098
# Epoch   0 Batch   84/134 - Train Accuracy:  0.469, Validation Accuracy:  0.498, Loss:  2.060
# Epoch   0 Batch   85/134 - Train Accuracy:  0.462, Validation Accuracy:  0.490, Loss:  2.065
# Epoch   0 Batch   86/134 - Train Accuracy:  0.432, Validation Accuracy:  0.468, Loss:  2.040
# Epoch   0 Batch   87/134 - Train Accuracy:  0.464, Validation Accuracy:  0.491, Loss:  2.040
# Epoch   0 Batch   88/134 - Train Accuracy:  0.497, Validation Accuracy:  0.506, Loss:  1.912
# Epoch   0 Batch   89/134 - Train Accuracy:  0.463, Validation Accuracy:  0.489, Loss:  2.005
# Epoch   0 Batch   90/134 - Train Accuracy:  0.438, Validation Accuracy:  0.472, Loss:  1.978
# Epoch   0 Batch   91/134 - Train Accuracy:  0.523, Validation Accuracy:  0.482, Loss:  1.721
# Epoch   0 Batch   92/134 - Train Accuracy:  0.471, Validation Accuracy:  0.495, Loss:  1.928
# Epoch   0 Batch   93/134 - Train Accuracy:  0.476, Validation Accuracy:  0.493, Loss:  1.889
# Epoch   0 Batch   94/134 - Train Accuracy:  0.455, Validation Accuracy:  0.481, Loss:  1.900
# Epoch   0 Batch   95/134 - Train Accuracy:  0.461, Validation Accuracy:  0.487, Loss:  1.925
# Epoch   0 Batch   96/134 - Train Accuracy:  0.478, Validation Accuracy:  0.502, Loss:  1.892
# Epoch   0 Batch   97/134 - Train Accuracy:  0.452, Validation Accuracy:  0.488, Loss:  1.894
# Epoch   0 Batch   98/134 - Train Accuracy:  0.422, Validation Accuracy:  0.484, Loss:  1.962
# Epoch   0 Batch   99/134 - Train Accuracy:  0.475, Validation Accuracy:  0.499, Loss:  1.861
# Epoch   0 Batch  100/134 - Train Accuracy:  0.461, Validation Accuracy:  0.492, Loss:  1.842
# Epoch   0 Batch  101/134 - Train Accuracy:  0.431, Validation Accuracy:  0.484, Loss:  1.896
# Epoch   0 Batch  102/134 - Train Accuracy:  0.458, Validation Accuracy:  0.491, Loss:  1.813
# Epoch   0 Batch  103/134 - Train Accuracy:  0.497, Validation Accuracy:  0.502, Loss:  1.725
# Epoch   0 Batch  104/134 - Train Accuracy:  0.469, Validation Accuracy:  0.494, Loss:  1.762
# Epoch   0 Batch  105/134 - Train Accuracy:  0.469, Validation Accuracy:  0.488, Loss:  1.726
# Epoch   0 Batch  106/134 - Train Accuracy:  0.482, Validation Accuracy:  0.502, Loss:  1.730
# Epoch   0 Batch  107/134 - Train Accuracy:  0.511, Validation Accuracy:  0.508, Loss:  1.649
# Epoch   0 Batch  108/134 - Train Accuracy:  0.444, Validation Accuracy:  0.497, Loss:  1.797
# Epoch   0 Batch  109/134 - Train Accuracy:  0.499, Validation Accuracy:  0.504, Loss:  1.620
# Epoch   0 Batch  110/134 - Train Accuracy:  0.497, Validation Accuracy:  0.515, Loss:  1.658
# Epoch   0 Batch  111/134 - Train Accuracy:  0.478, Validation Accuracy:  0.499, Loss:  1.652
# Epoch   0 Batch  112/134 - Train Accuracy:  0.481, Validation Accuracy:  0.505, Loss:  1.649
# Epoch   0 Batch  113/134 - Train Accuracy:  0.547, Validation Accuracy:  0.509, Loss:  1.448
# Epoch   0 Batch  114/134 - Train Accuracy:  0.476, Validation Accuracy:  0.504, Loss:  1.639
# Epoch   0 Batch  115/134 - Train Accuracy:  0.439, Validation Accuracy:  0.498, Loss:  1.703
# Epoch   0 Batch  116/134 - Train Accuracy:  0.483, Validation Accuracy:  0.506, Loss:  1.622
# Epoch   0 Batch  117/134 - Train Accuracy:  0.477, Validation Accuracy:  0.504, Loss:  1.604
# Epoch   0 Batch  118/134 - Train Accuracy:  0.464, Validation Accuracy:  0.494, Loss:  1.583
# Epoch   0 Batch  119/134 - Train Accuracy:  0.515, Validation Accuracy:  0.498, Loss:  1.450
# Epoch   0 Batch  120/134 - Train Accuracy:  0.487, Validation Accuracy:  0.514, Loss:  1.559
# Epoch   0 Batch  121/134 - Train Accuracy:  0.466, Validation Accuracy:  0.494, Loss:  1.537
# Epoch   0 Batch  122/134 - Train Accuracy:  0.473, Validation Accuracy:  0.505, Loss:  1.551
# Epoch   0 Batch  123/134 - Train Accuracy:  0.479, Validation Accuracy:  0.508, Loss:  1.520
# Epoch   0 Batch  124/134 - Train Accuracy:  0.492, Validation Accuracy:  0.492, Loss:  1.444
# Epoch   0 Batch  125/134 - Train Accuracy:  0.460, Validation Accuracy:  0.499, Loss:  1.517
# Epoch   0 Batch  126/134 - Train Accuracy:  0.469, Validation Accuracy:  0.499, Loss:  1.495
# Epoch   0 Batch  127/134 - Train Accuracy:  0.487, Validation Accuracy:  0.497, Loss:  1.440
# Epoch   0 Batch  128/134 - Train Accuracy:  0.469, Validation Accuracy:  0.504, Loss:  1.496
# Epoch   0 Batch  129/134 - Train Accuracy:  0.486, Validation Accuracy:  0.504, Loss:  1.474
# Epoch   0 Batch  130/134 - Train Accuracy:  0.469, Validation Accuracy:  0.504, Loss:  1.471
# Epoch   0 Batch  131/134 - Train Accuracy:  0.458, Validation Accuracy:  0.502, Loss:  1.529
# Epoch   0 Batch  132/134 - Train Accuracy:  0.482, Validation Accuracy:  0.507, Loss:  1.422
# Epoch   1 Batch    0/134 - Train Accuracy:  0.474, Validation Accuracy:  0.508, Loss:  1.444
# Epoch   1 Batch    1/134 - Train Accuracy:  0.457, Validation Accuracy:  0.505, Loss:  1.489
# Epoch   1 Batch    2/134 - Train Accuracy:  0.485, Validation Accuracy:  0.505, Loss:  1.388
# Epoch   1 Batch    3/134 - Train Accuracy:  0.483, Validation Accuracy:  0.504, Loss:  1.402
# Epoch   1 Batch    4/134 - Train Accuracy:  0.487, Validation Accuracy:  0.512, Loss:  1.385
# Epoch   1 Batch    5/134 - Train Accuracy:  0.460, Validation Accuracy:  0.493, Loss:  1.392
# Epoch   1 Batch    6/134 - Train Accuracy:  0.506, Validation Accuracy:  0.508, Loss:  1.309
# Epoch   1 Batch    7/134 - Train Accuracy:  0.461, Validation Accuracy:  0.494, Loss:  1.374
# Epoch   1 Batch    8/134 - Train Accuracy:  0.475, Validation Accuracy:  0.500, Loss:  1.343
# Epoch   1 Batch    9/134 - Train Accuracy:  0.502, Validation Accuracy:  0.501, Loss:  1.281
# Epoch   1 Batch   10/134 - Train Accuracy:  0.463, Validation Accuracy:  0.487, Loss:  1.360
# Epoch   1 Batch   11/134 - Train Accuracy:  0.492, Validation Accuracy:  0.509, Loss:  1.342
# Epoch   1 Batch   12/134 - Train Accuracy:  0.497, Validation Accuracy:  0.499, Loss:  1.267
# Epoch   1 Batch   13/134 - Train Accuracy:  0.463, Validation Accuracy:  0.503, Loss:  1.340
# Epoch   1 Batch   14/134 - Train Accuracy:  0.479, Validation Accuracy:  0.510, Loss:  1.306
# Epoch   1 Batch   15/134 - Train Accuracy:  0.481, Validation Accuracy:  0.507, Loss:  1.303
# Epoch   1 Batch   16/134 - Train Accuracy:  0.489, Validation Accuracy:  0.513, Loss:  1.282
# Epoch   1 Batch   17/134 - Train Accuracy:  0.493, Validation Accuracy:  0.512, Loss:  1.294
# Epoch   1 Batch   18/134 - Train Accuracy:  0.481, Validation Accuracy:  0.506, Loss:  1.297
# Epoch   1 Batch   19/134 - Train Accuracy:  0.487, Validation Accuracy:  0.515, Loss:  1.269
# Epoch   1 Batch   20/134 - Train Accuracy:  0.504, Validation Accuracy:  0.512, Loss:  1.222
# Epoch   1 Batch   21/134 - Train Accuracy:  0.502, Validation Accuracy:  0.524, Loss:  1.260
# Epoch   1 Batch   22/134 - Train Accuracy:  0.466, Validation Accuracy:  0.516, Loss:  1.307
# Epoch   1 Batch   23/134 - Train Accuracy:  0.517, Validation Accuracy:  0.519, Loss:  1.170
# Epoch   1 Batch   24/134 - Train Accuracy:  0.468, Validation Accuracy:  0.513, Loss:  1.291
# Epoch   1 Batch   25/134 - Train Accuracy:  0.495, Validation Accuracy:  0.530, Loss:  1.238
# Epoch   1 Batch   26/134 - Train Accuracy:  0.450, Validation Accuracy:  0.496, Loss:  1.296
# Epoch   1 Batch   27/134 - Train Accuracy:  0.520, Validation Accuracy:  0.537, Loss:  1.235
# Epoch   1 Batch   28/134 - Train Accuracy:  0.501, Validation Accuracy:  0.520, Loss:  1.229
# Epoch   1 Batch   29/134 - Train Accuracy:  0.521, Validation Accuracy:  0.528, Loss:  1.157
# Epoch   1 Batch   30/134 - Train Accuracy:  0.527, Validation Accuracy:  0.530, Loss:  1.156
# Epoch   1 Batch   31/134 - Train Accuracy:  0.486, Validation Accuracy:  0.517, Loss:  1.201
# Epoch   1 Batch   32/134 - Train Accuracy:  0.530, Validation Accuracy:  0.531, Loss:  1.141
# Epoch   1 Batch   33/134 - Train Accuracy:  0.504, Validation Accuracy:  0.537, Loss:  1.203
# Epoch   1 Batch   34/134 - Train Accuracy:  0.499, Validation Accuracy:  0.518, Loss:  1.203
# Epoch   1 Batch   35/134 - Train Accuracy:  0.536, Validation Accuracy:  0.540, Loss:  1.142
# Epoch   1 Batch   36/134 - Train Accuracy:  0.525, Validation Accuracy:  0.543, Loss:  1.167
# Epoch   1 Batch   37/134 - Train Accuracy:  0.488, Validation Accuracy:  0.525, Loss:  1.176
# Epoch   1 Batch   38/134 - Train Accuracy:  0.524, Validation Accuracy:  0.540, Loss:  1.165
# Epoch   1 Batch   39/134 - Train Accuracy:  0.524, Validation Accuracy:  0.541, Loss:  1.141
# Epoch   1 Batch   40/134 - Train Accuracy:  0.507, Validation Accuracy:  0.529, Loss:  1.139
# Epoch   1 Batch   41/134 - Train Accuracy:  0.537, Validation Accuracy:  0.549, Loss:  1.129
# Epoch   1 Batch   42/134 - Train Accuracy:  0.515, Validation Accuracy:  0.546, Loss:  1.142
# Epoch   1 Batch   43/134 - Train Accuracy:  0.505, Validation Accuracy:  0.537, Loss:  1.145
# Epoch   1 Batch   44/134 - Train Accuracy:  0.515, Validation Accuracy:  0.545, Loss:  1.129
# Epoch   1 Batch   45/134 - Train Accuracy:  0.511, Validation Accuracy:  0.539, Loss:  1.111
# Epoch   1 Batch   46/134 - Train Accuracy:  0.528, Validation Accuracy:  0.535, Loss:  1.078
# Epoch   1 Batch   47/134 - Train Accuracy:  0.513, Validation Accuracy:  0.535, Loss:  1.103
# Epoch   1 Batch   48/134 - Train Accuracy:  0.514, Validation Accuracy:  0.537, Loss:  1.093
# Epoch   1 Batch   49/134 - Train Accuracy:  0.527, Validation Accuracy:  0.546, Loss:  1.084
# Epoch   1 Batch   50/134 - Train Accuracy:  0.503, Validation Accuracy:  0.534, Loss:  1.093
# Epoch   1 Batch   51/134 - Train Accuracy:  0.516, Validation Accuracy:  0.546, Loss:  1.088
# Epoch   1 Batch   52/134 - Train Accuracy:  0.520, Validation Accuracy:  0.552, Loss:  1.092
# Epoch   1 Batch   53/134 - Train Accuracy:  0.501, Validation Accuracy:  0.537, Loss:  1.076
# Epoch   1 Batch   54/134 - Train Accuracy:  0.522, Validation Accuracy:  0.552, Loss:  1.080
# Epoch   1 Batch   55/134 - Train Accuracy:  0.519, Validation Accuracy:  0.550, Loss:  1.077
# Epoch   1 Batch   56/134 - Train Accuracy:  0.536, Validation Accuracy:  0.544, Loss:  1.015
# Epoch   1 Batch   57/134 - Train Accuracy:  0.531, Validation Accuracy:  0.553, Loss:  1.050
# Epoch   1 Batch   58/134 - Train Accuracy:  0.533, Validation Accuracy:  0.550, Loss:  1.034
# Epoch   1 Batch   59/134 - Train Accuracy:  0.498, Validation Accuracy:  0.543, Loss:  1.096
# Epoch   1 Batch   60/134 - Train Accuracy:  0.521, Validation Accuracy:  0.551, Loss:  1.035
# Epoch   1 Batch   61/134 - Train Accuracy:  0.527, Validation Accuracy:  0.553, Loss:  1.026
# Epoch   1 Batch   62/134 - Train Accuracy:  0.538, Validation Accuracy:  0.555, Loss:  1.012
# Epoch   1 Batch   63/134 - Train Accuracy:  0.548, Validation Accuracy:  0.561, Loss:  1.026
# Epoch   1 Batch   64/134 - Train Accuracy:  0.536, Validation Accuracy:  0.562, Loss:  1.033
# Epoch   1 Batch   65/134 - Train Accuracy:  0.539, Validation Accuracy:  0.557, Loss:  1.016
# Epoch   1 Batch   66/134 - Train Accuracy:  0.526, Validation Accuracy:  0.561, Loss:  0.997
# Epoch   1 Batch   67/134 - Train Accuracy:  0.508, Validation Accuracy:  0.563, Loss:  1.081
# Epoch   1 Batch   68/134 - Train Accuracy:  0.527, Validation Accuracy:  0.564, Loss:  1.046
# Epoch   1 Batch   69/134 - Train Accuracy:  0.551, Validation Accuracy:  0.561, Loss:  0.997
# Epoch   1 Batch   70/134 - Train Accuracy:  0.552, Validation Accuracy:  0.565, Loss:  0.974
# Epoch   1 Batch   71/134 - Train Accuracy:  0.543, Validation Accuracy:  0.563, Loss:  0.987
# Epoch   1 Batch   72/134 - Train Accuracy:  0.537, Validation Accuracy:  0.564, Loss:  0.985
# Epoch   1 Batch   73/134 - Train Accuracy:  0.552, Validation Accuracy:  0.563, Loss:  0.956
# Epoch   1 Batch   74/134 - Train Accuracy:  0.545, Validation Accuracy:  0.566, Loss:  0.988
# Epoch   1 Batch   75/134 - Train Accuracy:  0.567, Validation Accuracy:  0.564, Loss:  0.942
# Epoch   1 Batch   76/134 - Train Accuracy:  0.543, Validation Accuracy:  0.565, Loss:  0.965
# Epoch   1 Batch   77/134 - Train Accuracy:  0.565, Validation Accuracy:  0.558, Loss:  0.923
# Epoch   1 Batch   78/134 - Train Accuracy:  0.541, Validation Accuracy:  0.560, Loss:  0.956
# Epoch   1 Batch   79/134 - Train Accuracy:  0.545, Validation Accuracy:  0.565, Loss:  0.972
# Epoch   1 Batch   80/134 - Train Accuracy:  0.535, Validation Accuracy:  0.563, Loss:  0.962
# Epoch   1 Batch   81/134 - Train Accuracy:  0.546, Validation Accuracy:  0.564, Loss:  0.952
# Epoch   1 Batch   82/134 - Train Accuracy:  0.563, Validation Accuracy:  0.564, Loss:  0.894
# Epoch   1 Batch   83/134 - Train Accuracy:  0.544, Validation Accuracy:  0.564, Loss:  0.955
# Epoch   1 Batch   84/134 - Train Accuracy:  0.545, Validation Accuracy:  0.568, Loss:  0.943
# Epoch   1 Batch   85/134 - Train Accuracy:  0.549, Validation Accuracy:  0.565, Loss:  0.946
# Epoch   1 Batch   86/134 - Train Accuracy:  0.543, Validation Accuracy:  0.565, Loss:  0.936
# Epoch   1 Batch   87/134 - Train Accuracy:  0.551, Validation Accuracy:  0.568, Loss:  0.943
# Epoch   1 Batch   88/134 - Train Accuracy:  0.561, Validation Accuracy:  0.569, Loss:  0.879
# Epoch   1 Batch   89/134 - Train Accuracy:  0.542, Validation Accuracy:  0.566, Loss:  0.924
# Epoch   1 Batch   90/134 - Train Accuracy:  0.539, Validation Accuracy:  0.567, Loss:  0.929
# Epoch   1 Batch   91/134 - Train Accuracy:  0.607, Validation Accuracy:  0.562, Loss:  0.801
# Epoch   1 Batch   92/134 - Train Accuracy:  0.545, Validation Accuracy:  0.567, Loss:  0.909
# Epoch   1 Batch   93/134 - Train Accuracy:  0.560, Validation Accuracy:  0.567, Loss:  0.894
# Epoch   1 Batch   94/134 - Train Accuracy:  0.550, Validation Accuracy:  0.568, Loss:  0.898
# Epoch   1 Batch   95/134 - Train Accuracy:  0.553, Validation Accuracy:  0.572, Loss:  0.909
# Epoch   1 Batch   96/134 - Train Accuracy:  0.564, Validation Accuracy:  0.579, Loss:  0.906
# Epoch   1 Batch   97/134 - Train Accuracy:  0.541, Validation Accuracy:  0.569, Loss:  0.911
# Epoch   1 Batch   98/134 - Train Accuracy:  0.522, Validation Accuracy:  0.575, Loss:  0.957
# Epoch   1 Batch   99/134 - Train Accuracy:  0.551, Validation Accuracy:  0.573, Loss:  0.897
# Epoch   1 Batch  100/134 - Train Accuracy:  0.544, Validation Accuracy:  0.570, Loss:  0.895
# Epoch   1 Batch  101/134 - Train Accuracy:  0.531, Validation Accuracy:  0.574, Loss:  0.937
# Epoch   1 Batch  102/134 - Train Accuracy:  0.547, Validation Accuracy:  0.574, Loss:  0.884
# Epoch   1 Batch  103/134 - Train Accuracy:  0.573, Validation Accuracy:  0.577, Loss:  0.847
# Epoch   1 Batch  104/134 - Train Accuracy:  0.566, Validation Accuracy:  0.580, Loss:  0.858
# Epoch   1 Batch  105/134 - Train Accuracy:  0.571, Validation Accuracy:  0.581, Loss:  0.873
# Epoch   1 Batch  106/134 - Train Accuracy:  0.557, Validation Accuracy:  0.574, Loss:  0.866
# Epoch   1 Batch  107/134 - Train Accuracy:  0.574, Validation Accuracy:  0.578, Loss:  0.838
# Epoch   1 Batch  108/134 - Train Accuracy:  0.546, Validation Accuracy:  0.579, Loss:  0.901
# Epoch   1 Batch  109/134 - Train Accuracy:  0.572, Validation Accuracy:  0.576, Loss:  0.822
# Epoch   1 Batch  110/134 - Train Accuracy:  0.559, Validation Accuracy:  0.575, Loss:  0.844
# Epoch   1 Batch  111/134 - Train Accuracy:  0.560, Validation Accuracy:  0.577, Loss:  0.858
# Epoch   1 Batch  112/134 - Train Accuracy:  0.550, Validation Accuracy:  0.575, Loss:  0.842
# Epoch   1 Batch  113/134 - Train Accuracy:  0.605, Validation Accuracy:  0.572, Loss:  0.748
# Epoch   1 Batch  114/134 - Train Accuracy:  0.547, Validation Accuracy:  0.577, Loss:  0.841
# Epoch   1 Batch  115/134 - Train Accuracy:  0.533, Validation Accuracy:  0.576, Loss:  0.885
# Epoch   1 Batch  116/134 - Train Accuracy:  0.561, Validation Accuracy:  0.577, Loss:  0.849
# Epoch   1 Batch  117/134 - Train Accuracy:  0.560, Validation Accuracy:  0.583, Loss:  0.835
# Epoch   1 Batch  118/134 - Train Accuracy:  0.557, Validation Accuracy:  0.582, Loss:  0.837
# Epoch   1 Batch  119/134 - Train Accuracy:  0.604, Validation Accuracy:  0.581, Loss:  0.757
# Epoch   1 Batch  120/134 - Train Accuracy:  0.563, Validation Accuracy:  0.584, Loss:  0.838
# Epoch   1 Batch  121/134 - Train Accuracy:  0.574, Validation Accuracy:  0.589, Loss:  0.814
# Epoch   1 Batch  122/134 - Train Accuracy:  0.560, Validation Accuracy:  0.583, Loss:  0.832
# Epoch   1 Batch  123/134 - Train Accuracy:  0.567, Validation Accuracy:  0.587, Loss:  0.820
# Epoch   1 Batch  124/134 - Train Accuracy:  0.588, Validation Accuracy:  0.582, Loss:  0.775
# Epoch   1 Batch  125/134 - Train Accuracy:  0.562, Validation Accuracy:  0.575, Loss:  0.814
# Epoch   1 Batch  126/134 - Train Accuracy:  0.562, Validation Accuracy:  0.579, Loss:  0.818
# Epoch   1 Batch  127/134 - Train Accuracy:  0.576, Validation Accuracy:  0.581, Loss:  0.785
# Epoch   1 Batch  128/134 - Train Accuracy:  0.559, Validation Accuracy:  0.587, Loss:  0.820
# Epoch   1 Batch  129/134 - Train Accuracy:  0.584, Validation Accuracy:  0.592, Loss:  0.806
# Epoch   1 Batch  130/134 - Train Accuracy:  0.575, Validation Accuracy:  0.595, Loss:  0.809
# Epoch   1 Batch  131/134 - Train Accuracy:  0.563, Validation Accuracy:  0.596, Loss:  0.839
# Epoch   1 Batch  132/134 - Train Accuracy:  0.585, Validation Accuracy:  0.595, Loss:  0.786
# Epoch   2 Batch    0/134 - Train Accuracy:  0.567, Validation Accuracy:  0.594, Loss:  0.792
# Epoch   2 Batch    1/134 - Train Accuracy:  0.554, Validation Accuracy:  0.594, Loss:  0.826
# Epoch   2 Batch    2/134 - Train Accuracy:  0.578, Validation Accuracy:  0.594, Loss:  0.775
# Epoch   2 Batch    3/134 - Train Accuracy:  0.571, Validation Accuracy:  0.585, Loss:  0.788
# Epoch   2 Batch    4/134 - Train Accuracy:  0.570, Validation Accuracy:  0.585, Loss:  0.783
# Epoch   2 Batch    5/134 - Train Accuracy:  0.570, Validation Accuracy:  0.591, Loss:  0.798
# Epoch   2 Batch    6/134 - Train Accuracy:  0.600, Validation Accuracy:  0.593, Loss:  0.741
# Epoch   2 Batch    7/134 - Train Accuracy:  0.578, Validation Accuracy:  0.597, Loss:  0.776
# Epoch   2 Batch    8/134 - Train Accuracy:  0.584, Validation Accuracy:  0.601, Loss:  0.761
# Epoch   2 Batch    9/134 - Train Accuracy:  0.615, Validation Accuracy:  0.600, Loss:  0.732
# Epoch   2 Batch   10/134 - Train Accuracy:  0.593, Validation Accuracy:  0.600, Loss:  0.770
# Epoch   2 Batch   11/134 - Train Accuracy:  0.597, Validation Accuracy:  0.599, Loss:  0.773
# Epoch   2 Batch   12/134 - Train Accuracy:  0.611, Validation Accuracy:  0.599, Loss:  0.734
# Epoch   2 Batch   13/134 - Train Accuracy:  0.575, Validation Accuracy:  0.603, Loss:  0.774
# Epoch   2 Batch   14/134 - Train Accuracy:  0.592, Validation Accuracy:  0.605, Loss:  0.752
# Epoch   2 Batch   15/134 - Train Accuracy:  0.590, Validation Accuracy:  0.605, Loss:  0.753
# Epoch   2 Batch   16/134 - Train Accuracy:  0.597, Validation Accuracy:  0.609, Loss:  0.744
# Epoch   2 Batch   17/134 - Train Accuracy:  0.592, Validation Accuracy:  0.608, Loss:  0.766
# Epoch   2 Batch   18/134 - Train Accuracy:  0.606, Validation Accuracy:  0.612, Loss:  0.758
# Epoch   2 Batch   19/134 - Train Accuracy:  0.607, Validation Accuracy:  0.614, Loss:  0.744
# Epoch   2 Batch   20/134 - Train Accuracy:  0.615, Validation Accuracy:  0.612, Loss:  0.722
# Epoch   2 Batch   21/134 - Train Accuracy:  0.607, Validation Accuracy:  0.614, Loss:  0.754
# Epoch   2 Batch   22/134 - Train Accuracy:  0.590, Validation Accuracy:  0.613, Loss:  0.777
# Epoch   2 Batch   23/134 - Train Accuracy:  0.611, Validation Accuracy:  0.606, Loss:  0.694
# Epoch   2 Batch   24/134 - Train Accuracy:  0.571, Validation Accuracy:  0.601, Loss:  0.769
# Epoch   2 Batch   25/134 - Train Accuracy:  0.588, Validation Accuracy:  0.607, Loss:  0.734
# Epoch   2 Batch   26/134 - Train Accuracy:  0.579, Validation Accuracy:  0.610, Loss:  0.772
# Epoch   2 Batch   27/134 - Train Accuracy:  0.606, Validation Accuracy:  0.610, Loss:  0.738
# Epoch   2 Batch   28/134 - Train Accuracy:  0.600, Validation Accuracy:  0.610, Loss:  0.742
# Epoch   2 Batch   29/134 - Train Accuracy:  0.621, Validation Accuracy:  0.616, Loss:  0.693
# Epoch   2 Batch   30/134 - Train Accuracy:  0.618, Validation Accuracy:  0.618, Loss:  0.696
# Epoch   2 Batch   31/134 - Train Accuracy:  0.595, Validation Accuracy:  0.620, Loss:  0.730
# Epoch   2 Batch   32/134 - Train Accuracy:  0.617, Validation Accuracy:  0.623, Loss:  0.694
# Epoch   2 Batch   33/134 - Train Accuracy:  0.599, Validation Accuracy:  0.617, Loss:  0.736
# Epoch   2 Batch   34/134 - Train Accuracy:  0.609, Validation Accuracy:  0.622, Loss:  0.747
# Epoch   2 Batch   35/134 - Train Accuracy:  0.623, Validation Accuracy:  0.625, Loss:  0.698
# Epoch   2 Batch   36/134 - Train Accuracy:  0.618, Validation Accuracy:  0.623, Loss:  0.718
# Epoch   2 Batch   37/134 - Train Accuracy:  0.597, Validation Accuracy:  0.621, Loss:  0.727
# Epoch   2 Batch   38/134 - Train Accuracy:  0.620, Validation Accuracy:  0.624, Loss:  0.712
# Epoch   2 Batch   39/134 - Train Accuracy:  0.615, Validation Accuracy:  0.624, Loss:  0.712
# Epoch   2 Batch   40/134 - Train Accuracy:  0.612, Validation Accuracy:  0.621, Loss:  0.706
# Epoch   2 Batch   41/134 - Train Accuracy:  0.609, Validation Accuracy:  0.623, Loss:  0.705
# Epoch   2 Batch   42/134 - Train Accuracy:  0.596, Validation Accuracy:  0.626, Loss:  0.707
# Epoch   2 Batch   43/134 - Train Accuracy:  0.605, Validation Accuracy:  0.620, Loss:  0.717
# Epoch   2 Batch   44/134 - Train Accuracy:  0.609, Validation Accuracy:  0.623, Loss:  0.714
# Epoch   2 Batch   45/134 - Train Accuracy:  0.611, Validation Accuracy:  0.624, Loss:  0.696
# Epoch   2 Batch   46/134 - Train Accuracy:  0.620, Validation Accuracy:  0.620, Loss:  0.681
# Epoch   2 Batch   47/134 - Train Accuracy:  0.605, Validation Accuracy:  0.618, Loss:  0.705
# Epoch   2 Batch   48/134 - Train Accuracy:  0.604, Validation Accuracy:  0.623, Loss:  0.697
# Epoch   2 Batch   49/134 - Train Accuracy:  0.623, Validation Accuracy:  0.624, Loss:  0.689
# Epoch   2 Batch   50/134 - Train Accuracy:  0.602, Validation Accuracy:  0.622, Loss:  0.699
# Epoch   2 Batch   51/134 - Train Accuracy:  0.604, Validation Accuracy:  0.622, Loss:  0.690
# Epoch   2 Batch   52/134 - Train Accuracy:  0.603, Validation Accuracy:  0.623, Loss:  0.696
# Epoch   2 Batch   53/134 - Train Accuracy:  0.605, Validation Accuracy:  0.623, Loss:  0.696
# Epoch   2 Batch   54/134 - Train Accuracy:  0.596, Validation Accuracy:  0.623, Loss:  0.693
# Epoch   2 Batch   55/134 - Train Accuracy:  0.606, Validation Accuracy:  0.621, Loss:  0.695
# Epoch   2 Batch   56/134 - Train Accuracy:  0.617, Validation Accuracy:  0.621, Loss:  0.667
# Epoch   2 Batch   57/134 - Train Accuracy:  0.597, Validation Accuracy:  0.612, Loss:  0.698
# Epoch   2 Batch   58/134 - Train Accuracy:  0.610, Validation Accuracy:  0.616, Loss:  0.703
# Epoch   2 Batch   59/134 - Train Accuracy:  0.593, Validation Accuracy:  0.614, Loss:  0.734
# Epoch   2 Batch   60/134 - Train Accuracy:  0.605, Validation Accuracy:  0.617, Loss:  0.681
# Epoch   2 Batch   61/134 - Train Accuracy:  0.608, Validation Accuracy:  0.624, Loss:  0.690
# Epoch   2 Batch   62/134 - Train Accuracy:  0.608, Validation Accuracy:  0.613, Loss:  0.676
# Epoch   2 Batch   63/134 - Train Accuracy:  0.618, Validation Accuracy:  0.619, Loss:  0.689
# Epoch   2 Batch   64/134 - Train Accuracy:  0.600, Validation Accuracy:  0.618, Loss:  0.681
# Epoch   2 Batch   65/134 - Train Accuracy:  0.609, Validation Accuracy:  0.622, Loss:  0.684
# Epoch   2 Batch   66/134 - Train Accuracy:  0.607, Validation Accuracy:  0.616, Loss:  0.660
# Epoch   2 Batch   67/134 - Train Accuracy:  0.582, Validation Accuracy:  0.625, Loss:  0.730
# Epoch   2 Batch   68/134 - Train Accuracy:  0.598, Validation Accuracy:  0.623, Loss:  0.705
# Epoch   2 Batch   69/134 - Train Accuracy:  0.617, Validation Accuracy:  0.623, Loss:  0.673
# Epoch   2 Batch   70/134 - Train Accuracy:  0.620, Validation Accuracy:  0.626, Loss:  0.657
# Epoch   2 Batch   71/134 - Train Accuracy:  0.618, Validation Accuracy:  0.627, Loss:  0.660
# Epoch   2 Batch   72/134 - Train Accuracy:  0.614, Validation Accuracy:  0.626, Loss:  0.660
# Epoch   2 Batch   73/134 - Train Accuracy:  0.626, Validation Accuracy:  0.624, Loss:  0.640
# Epoch   2 Batch   74/134 - Train Accuracy:  0.620, Validation Accuracy:  0.626, Loss:  0.674
# Epoch   2 Batch   75/134 - Train Accuracy:  0.638, Validation Accuracy:  0.626, Loss:  0.638
# Epoch   2 Batch   76/134 - Train Accuracy:  0.628, Validation Accuracy:  0.629, Loss:  0.651
# Epoch   2 Batch   77/134 - Train Accuracy:  0.644, Validation Accuracy:  0.631, Loss:  0.630
# Epoch   2 Batch   78/134 - Train Accuracy:  0.614, Validation Accuracy:  0.630, Loss:  0.660
# Epoch   2 Batch   79/134 - Train Accuracy:  0.618, Validation Accuracy:  0.629, Loss:  0.660
# Epoch   2 Batch   80/134 - Train Accuracy:  0.614, Validation Accuracy:  0.627, Loss:  0.656
# Epoch   2 Batch   81/134 - Train Accuracy:  0.625, Validation Accuracy:  0.627, Loss:  0.653
# Epoch   2 Batch   82/134 - Train Accuracy:  0.635, Validation Accuracy:  0.627, Loss:  0.620
# Epoch   2 Batch   83/134 - Train Accuracy:  0.611, Validation Accuracy:  0.624, Loss:  0.659
# Epoch   2 Batch   84/134 - Train Accuracy:  0.617, Validation Accuracy:  0.621, Loss:  0.651
# Epoch   2 Batch   85/134 - Train Accuracy:  0.622, Validation Accuracy:  0.624, Loss:  0.658
# Epoch   2 Batch   86/134 - Train Accuracy:  0.604, Validation Accuracy:  0.621, Loss:  0.647
# Epoch   2 Batch   87/134 - Train Accuracy:  0.617, Validation Accuracy:  0.624, Loss:  0.660
# Epoch   2 Batch   88/134 - Train Accuracy:  0.633, Validation Accuracy:  0.627, Loss:  0.611
# Epoch   2 Batch   89/134 - Train Accuracy:  0.620, Validation Accuracy:  0.627, Loss:  0.645
# Epoch   2 Batch   90/134 - Train Accuracy:  0.619, Validation Accuracy:  0.627, Loss:  0.648
# Epoch   2 Batch   91/134 - Train Accuracy:  0.668, Validation Accuracy:  0.628, Loss:  0.559
# Epoch   2 Batch   92/134 - Train Accuracy:  0.619, Validation Accuracy:  0.629, Loss:  0.633
# Epoch   2 Batch   93/134 - Train Accuracy:  0.628, Validation Accuracy:  0.631, Loss:  0.625
# Epoch   2 Batch   94/134 - Train Accuracy:  0.620, Validation Accuracy:  0.628, Loss:  0.624
# Epoch   2 Batch   95/134 - Train Accuracy:  0.627, Validation Accuracy:  0.626, Loss:  0.630
# Epoch   2 Batch   96/134 - Train Accuracy:  0.624, Validation Accuracy:  0.623, Loss:  0.640
# Epoch   2 Batch   97/134 - Train Accuracy:  0.608, Validation Accuracy:  0.630, Loss:  0.637
# Epoch   2 Batch   98/134 - Train Accuracy:  0.599, Validation Accuracy:  0.630, Loss:  0.668
# Epoch   2 Batch   99/134 - Train Accuracy:  0.615, Validation Accuracy:  0.628, Loss:  0.637
# Epoch   2 Batch  100/134 - Train Accuracy:  0.621, Validation Accuracy:  0.631, Loss:  0.632
# Epoch   2 Batch  101/134 - Train Accuracy:  0.601, Validation Accuracy:  0.633, Loss:  0.671
# Epoch   2 Batch  102/134 - Train Accuracy:  0.624, Validation Accuracy:  0.632, Loss:  0.624
# Epoch   2 Batch  103/134 - Train Accuracy:  0.640, Validation Accuracy:  0.635, Loss:  0.606
# Epoch   2 Batch  104/134 - Train Accuracy:  0.638, Validation Accuracy:  0.630, Loss:  0.615
# Epoch   2 Batch  105/134 - Train Accuracy:  0.626, Validation Accuracy:  0.632, Loss:  0.628
# Epoch   2 Batch  106/134 - Train Accuracy:  0.631, Validation Accuracy:  0.633, Loss:  0.624
# Epoch   2 Batch  107/134 - Train Accuracy:  0.643, Validation Accuracy:  0.631, Loss:  0.600
# Epoch   2 Batch  108/134 - Train Accuracy:  0.601, Validation Accuracy:  0.637, Loss:  0.651
# Epoch   2 Batch  109/134 - Train Accuracy:  0.645, Validation Accuracy:  0.636, Loss:  0.589
# Epoch   2 Batch  110/134 - Train Accuracy:  0.644, Validation Accuracy:  0.635, Loss:  0.612
# Epoch   2 Batch  111/134 - Train Accuracy:  0.624, Validation Accuracy:  0.637, Loss:  0.622
# Epoch   2 Batch  112/134 - Train Accuracy:  0.624, Validation Accuracy:  0.630, Loss:  0.610
# Epoch   2 Batch  113/134 - Train Accuracy:  0.676, Validation Accuracy:  0.638, Loss:  0.542
# Epoch   2 Batch  114/134 - Train Accuracy:  0.630, Validation Accuracy:  0.637, Loss:  0.608
# Epoch   2 Batch  115/134 - Train Accuracy:  0.596, Validation Accuracy:  0.630, Loss:  0.650
# Epoch   2 Batch  116/134 - Train Accuracy:  0.620, Validation Accuracy:  0.631, Loss:  0.628
# Epoch   2 Batch  117/134 - Train Accuracy:  0.627, Validation Accuracy:  0.638, Loss:  0.607
# Epoch   2 Batch  118/134 - Train Accuracy:  0.631, Validation Accuracy:  0.640, Loss:  0.603
# Epoch   2 Batch  119/134 - Train Accuracy:  0.655, Validation Accuracy:  0.636, Loss:  0.554
# Epoch   2 Batch  120/134 - Train Accuracy:  0.622, Validation Accuracy:  0.641, Loss:  0.612
# Epoch   2 Batch  121/134 - Train Accuracy:  0.635, Validation Accuracy:  0.640, Loss:  0.599
# Epoch   2 Batch  122/134 - Train Accuracy:  0.604, Validation Accuracy:  0.628, Loss:  0.611
# Epoch   2 Batch  123/134 - Train Accuracy:  0.626, Validation Accuracy:  0.628, Loss:  0.605
# Epoch   2 Batch  124/134 - Train Accuracy:  0.650, Validation Accuracy:  0.631, Loss:  0.577
# Epoch   2 Batch  125/134 - Train Accuracy:  0.636, Validation Accuracy:  0.635, Loss:  0.610
# Epoch   2 Batch  126/134 - Train Accuracy:  0.612, Validation Accuracy:  0.636, Loss:  0.615
# Epoch   2 Batch  127/134 - Train Accuracy:  0.646, Validation Accuracy:  0.640, Loss:  0.584
# Epoch   2 Batch  128/134 - Train Accuracy:  0.606, Validation Accuracy:  0.634, Loss:  0.609
# Epoch   2 Batch  129/134 - Train Accuracy:  0.624, Validation Accuracy:  0.633, Loss:  0.605
# Epoch   2 Batch  130/134 - Train Accuracy:  0.622, Validation Accuracy:  0.635, Loss:  0.609
# Epoch   2 Batch  131/134 - Train Accuracy:  0.616, Validation Accuracy:  0.641, Loss:  0.621
# Epoch   2 Batch  132/134 - Train Accuracy:  0.629, Validation Accuracy:  0.638, Loss:  0.594
# Epoch   3 Batch    0/134 - Train Accuracy:  0.626, Validation Accuracy:  0.636, Loss:  0.598
# Epoch   3 Batch    1/134 - Train Accuracy:  0.611, Validation Accuracy:  0.641, Loss:  0.620
# Epoch   3 Batch    2/134 - Train Accuracy:  0.621, Validation Accuracy:  0.639, Loss:  0.590
# Epoch   3 Batch    3/134 - Train Accuracy:  0.634, Validation Accuracy:  0.643, Loss:  0.594
# Epoch   3 Batch    4/134 - Train Accuracy:  0.630, Validation Accuracy:  0.648, Loss:  0.595
# Epoch   3 Batch    5/134 - Train Accuracy:  0.629, Validation Accuracy:  0.635, Loss:  0.603
# Epoch   3 Batch    6/134 - Train Accuracy:  0.641, Validation Accuracy:  0.634, Loss:  0.555
# Epoch   3 Batch    7/134 - Train Accuracy:  0.638, Validation Accuracy:  0.646, Loss:  0.590
# Epoch   3 Batch    8/134 - Train Accuracy:  0.638, Validation Accuracy:  0.651, Loss:  0.579
# Epoch   3 Batch    9/134 - Train Accuracy:  0.659, Validation Accuracy:  0.644, Loss:  0.550
# Epoch   3 Batch   10/134 - Train Accuracy:  0.644, Validation Accuracy:  0.650, Loss:  0.578
# Epoch   3 Batch   11/134 - Train Accuracy:  0.639, Validation Accuracy:  0.649, Loss:  0.580
# Epoch   3 Batch   12/134 - Train Accuracy:  0.664, Validation Accuracy:  0.649, Loss:  0.552
# Epoch   3 Batch   13/134 - Train Accuracy:  0.627, Validation Accuracy:  0.655, Loss:  0.589
# Epoch   3 Batch   14/134 - Train Accuracy:  0.647, Validation Accuracy:  0.654, Loss:  0.577
# Epoch   3 Batch   15/134 - Train Accuracy:  0.637, Validation Accuracy:  0.648, Loss:  0.564
# Epoch   3 Batch   16/134 - Train Accuracy:  0.643, Validation Accuracy:  0.653, Loss:  0.566
# Epoch   3 Batch   17/134 - Train Accuracy:  0.645, Validation Accuracy:  0.657, Loss:  0.583
# Epoch   3 Batch   18/134 - Train Accuracy:  0.649, Validation Accuracy:  0.657, Loss:  0.572
# Epoch   3 Batch   19/134 - Train Accuracy:  0.643, Validation Accuracy:  0.656, Loss:  0.569
# Epoch   3 Batch   20/134 - Train Accuracy:  0.657, Validation Accuracy:  0.653, Loss:  0.549
# Epoch   3 Batch   21/134 - Train Accuracy:  0.645, Validation Accuracy:  0.653, Loss:  0.567
# Epoch   3 Batch   22/134 - Train Accuracy:  0.629, Validation Accuracy:  0.655, Loss:  0.593
# Epoch   3 Batch   23/134 - Train Accuracy:  0.662, Validation Accuracy:  0.651, Loss:  0.532
# Epoch   3 Batch   24/134 - Train Accuracy:  0.617, Validation Accuracy:  0.638, Loss:  0.587
# Epoch   3 Batch   25/134 - Train Accuracy:  0.632, Validation Accuracy:  0.653, Loss:  0.558
# Epoch   3 Batch   26/134 - Train Accuracy:  0.625, Validation Accuracy:  0.646, Loss:  0.588
# Epoch   3 Batch   27/134 - Train Accuracy:  0.652, Validation Accuracy:  0.648, Loss:  0.562
# Epoch   3 Batch   28/134 - Train Accuracy:  0.646, Validation Accuracy:  0.645, Loss:  0.564
# Epoch   3 Batch   29/134 - Train Accuracy:  0.661, Validation Accuracy:  0.650, Loss:  0.524
# Epoch   3 Batch   30/134 - Train Accuracy:  0.666, Validation Accuracy:  0.652, Loss:  0.531
# Epoch   3 Batch   31/134 - Train Accuracy:  0.637, Validation Accuracy:  0.650, Loss:  0.560
# Epoch   3 Batch   32/134 - Train Accuracy:  0.642, Validation Accuracy:  0.638, Loss:  0.535
# Epoch   3 Batch   33/134 - Train Accuracy:  0.624, Validation Accuracy:  0.644, Loss:  0.563
# Epoch   3 Batch   34/134 - Train Accuracy:  0.637, Validation Accuracy:  0.654, Loss:  0.570
# Epoch   3 Batch   35/134 - Train Accuracy:  0.642, Validation Accuracy:  0.646, Loss:  0.543
# Epoch   3 Batch   36/134 - Train Accuracy:  0.651, Validation Accuracy:  0.649, Loss:  0.551
# Epoch   3 Batch   37/134 - Train Accuracy:  0.636, Validation Accuracy:  0.652, Loss:  0.553
# Epoch   3 Batch   38/134 - Train Accuracy:  0.656, Validation Accuracy:  0.653, Loss:  0.546
# Epoch   3 Batch   39/134 - Train Accuracy:  0.654, Validation Accuracy:  0.657, Loss:  0.547
# Epoch   3 Batch   40/134 - Train Accuracy:  0.628, Validation Accuracy:  0.627, Loss:  0.560
# Epoch   3 Batch   41/134 - Train Accuracy:  0.642, Validation Accuracy:  0.648, Loss:  0.635
# Epoch   3 Batch   42/134 - Train Accuracy:  0.631, Validation Accuracy:  0.656, Loss:  0.596
# Epoch   3 Batch   43/134 - Train Accuracy:  0.628, Validation Accuracy:  0.644, Loss:  0.557
# Epoch   3 Batch   44/134 - Train Accuracy:  0.627, Validation Accuracy:  0.642, Loss:  0.575
# Epoch   3 Batch   45/134 - Train Accuracy:  0.643, Validation Accuracy:  0.645, Loss:  0.553
# Epoch   3 Batch   46/134 - Train Accuracy:  0.657, Validation Accuracy:  0.657, Loss:  0.548
# Epoch   3 Batch   47/134 - Train Accuracy:  0.646, Validation Accuracy:  0.661, Loss:  0.560
# Epoch   3 Batch   48/134 - Train Accuracy:  0.629, Validation Accuracy:  0.640, Loss:  0.557
# Epoch   3 Batch   49/134 - Train Accuracy:  0.653, Validation Accuracy:  0.640, Loss:  0.548
# Epoch   3 Batch   50/134 - Train Accuracy:  0.626, Validation Accuracy:  0.649, Loss:  0.559
# Epoch   3 Batch   51/134 - Train Accuracy:  0.640, Validation Accuracy:  0.654, Loss:  0.546
# Epoch   3 Batch   52/134 - Train Accuracy:  0.639, Validation Accuracy:  0.667, Loss:  0.555
# Epoch   3 Batch   53/134 - Train Accuracy:  0.644, Validation Accuracy:  0.660, Loss:  0.550
# Epoch   3 Batch   54/134 - Train Accuracy:  0.629, Validation Accuracy:  0.644, Loss:  0.542
# Epoch   3 Batch   55/134 - Train Accuracy:  0.631, Validation Accuracy:  0.649, Loss:  0.553
# Epoch   3 Batch   56/134 - Train Accuracy:  0.653, Validation Accuracy:  0.656, Loss:  0.524
# Epoch   3 Batch   57/134 - Train Accuracy:  0.644, Validation Accuracy:  0.658, Loss:  0.544
# Epoch   3 Batch   58/134 - Train Accuracy:  0.654, Validation Accuracy:  0.660, Loss:  0.536
# Epoch   3 Batch   59/134 - Train Accuracy:  0.641, Validation Accuracy:  0.662, Loss:  0.564
# Epoch   3 Batch   60/134 - Train Accuracy:  0.653, Validation Accuracy:  0.654, Loss:  0.531
# Epoch   3 Batch   61/134 - Train Accuracy:  0.648, Validation Accuracy:  0.663, Loss:  0.532
# Epoch   3 Batch   62/134 - Train Accuracy:  0.650, Validation Accuracy:  0.662, Loss:  0.531
# Epoch   3 Batch   63/134 - Train Accuracy:  0.656, Validation Accuracy:  0.657, Loss:  0.530
# Epoch   3 Batch   64/134 - Train Accuracy:  0.641, Validation Accuracy:  0.658, Loss:  0.536
# Epoch   3 Batch   65/134 - Train Accuracy:  0.644, Validation Accuracy:  0.662, Loss:  0.535
# Epoch   3 Batch   66/134 - Train Accuracy:  0.650, Validation Accuracy:  0.654, Loss:  0.523
# Epoch   3 Batch   67/134 - Train Accuracy:  0.623, Validation Accuracy:  0.657, Loss:  0.578
# Epoch   3 Batch   68/134 - Train Accuracy:  0.622, Validation Accuracy:  0.651, Loss:  0.569
# Epoch   3 Batch   69/134 - Train Accuracy:  0.651, Validation Accuracy:  0.664, Loss:  0.547
# Epoch   3 Batch   70/134 - Train Accuracy:  0.658, Validation Accuracy:  0.660, Loss:  0.515
# Epoch   3 Batch   71/134 - Train Accuracy:  0.644, Validation Accuracy:  0.659, Loss:  0.519
# Epoch   3 Batch   72/134 - Train Accuracy:  0.654, Validation Accuracy:  0.664, Loss:  0.524
# Epoch   3 Batch   73/134 - Train Accuracy:  0.665, Validation Accuracy:  0.667, Loss:  0.508
# Epoch   3 Batch   74/134 - Train Accuracy:  0.651, Validation Accuracy:  0.664, Loss:  0.530
# Epoch   3 Batch   75/134 - Train Accuracy:  0.676, Validation Accuracy:  0.659, Loss:  0.501
# Epoch   3 Batch   76/134 - Train Accuracy:  0.662, Validation Accuracy:  0.665, Loss:  0.516
# Epoch   3 Batch   77/134 - Train Accuracy:  0.667, Validation Accuracy:  0.664, Loss:  0.499
# Epoch   3 Batch   78/134 - Train Accuracy:  0.640, Validation Accuracy:  0.656, Loss:  0.515
# Epoch   3 Batch   79/134 - Train Accuracy:  0.664, Validation Accuracy:  0.673, Loss:  0.519
# Epoch   3 Batch   80/134 - Train Accuracy:  0.660, Validation Accuracy:  0.671, Loss:  0.516
# Epoch   3 Batch   81/134 - Train Accuracy:  0.667, Validation Accuracy:  0.669, Loss:  0.513
# Epoch   3 Batch   82/134 - Train Accuracy:  0.665, Validation Accuracy:  0.667, Loss:  0.484
# Epoch   3 Batch   83/134 - Train Accuracy:  0.650, Validation Accuracy:  0.669, Loss:  0.516
# Epoch   3 Batch   84/134 - Train Accuracy:  0.654, Validation Accuracy:  0.671, Loss:  0.515
# Epoch   3 Batch   85/134 - Train Accuracy:  0.667, Validation Accuracy:  0.673, Loss:  0.514
# Epoch   3 Batch   86/134 - Train Accuracy:  0.648, Validation Accuracy:  0.670, Loss:  0.503
# Epoch   3 Batch   87/134 - Train Accuracy:  0.662, Validation Accuracy:  0.671, Loss:  0.519
# Epoch   3 Batch   88/134 - Train Accuracy:  0.672, Validation Accuracy:  0.668, Loss:  0.478
# Epoch   3 Batch   89/134 - Train Accuracy:  0.659, Validation Accuracy:  0.672, Loss:  0.508
# Epoch   3 Batch   90/134 - Train Accuracy:  0.657, Validation Accuracy:  0.665, Loss:  0.519
# Epoch   3 Batch   91/134 - Train Accuracy:  0.704, Validation Accuracy:  0.678, Loss:  0.447
# Epoch   3 Batch   92/134 - Train Accuracy:  0.666, Validation Accuracy:  0.675, Loss:  0.493
# Epoch   3 Batch   93/134 - Train Accuracy:  0.669, Validation Accuracy:  0.668, Loss:  0.488
# Epoch   3 Batch   94/134 - Train Accuracy:  0.655, Validation Accuracy:  0.670, Loss:  0.505
# Epoch   3 Batch   95/134 - Train Accuracy:  0.669, Validation Accuracy:  0.677, Loss:  0.502
# Epoch   3 Batch   96/134 - Train Accuracy:  0.668, Validation Accuracy:  0.671, Loss:  0.495
# Epoch   3 Batch   97/134 - Train Accuracy:  0.646, Validation Accuracy:  0.667, Loss:  0.506
# Epoch   3 Batch   98/134 - Train Accuracy:  0.647, Validation Accuracy:  0.676, Loss:  0.538
# Epoch   3 Batch   99/134 - Train Accuracy:  0.671, Validation Accuracy:  0.674, Loss:  0.501
# Epoch   3 Batch  100/134 - Train Accuracy:  0.659, Validation Accuracy:  0.671, Loss:  0.492
# Epoch   3 Batch  101/134 - Train Accuracy:  0.653, Validation Accuracy:  0.682, Loss:  0.534
# Epoch   3 Batch  102/134 - Train Accuracy:  0.670, Validation Accuracy:  0.678, Loss:  0.492
# Epoch   3 Batch  103/134 - Train Accuracy:  0.677, Validation Accuracy:  0.676, Loss:  0.472
# Epoch   3 Batch  104/134 - Train Accuracy:  0.680, Validation Accuracy:  0.676, Loss:  0.482
# Epoch   3 Batch  105/134 - Train Accuracy:  0.672, Validation Accuracy:  0.677, Loss:  0.487
# Epoch   3 Batch  106/134 - Train Accuracy:  0.673, Validation Accuracy:  0.678, Loss:  0.494
# Epoch   3 Batch  107/134 - Train Accuracy:  0.690, Validation Accuracy:  0.680, Loss:  0.468
# Epoch   3 Batch  108/134 - Train Accuracy:  0.650, Validation Accuracy:  0.682, Loss:  0.508
# Epoch   3 Batch  109/134 - Train Accuracy:  0.701, Validation Accuracy:  0.682, Loss:  0.463
# Epoch   3 Batch  110/134 - Train Accuracy:  0.682, Validation Accuracy:  0.675, Loss:  0.474
# Epoch   3 Batch  111/134 - Train Accuracy:  0.673, Validation Accuracy:  0.681, Loss:  0.489
# Epoch   3 Batch  112/134 - Train Accuracy:  0.687, Validation Accuracy:  0.683, Loss:  0.472
# Epoch   3 Batch  113/134 - Train Accuracy:  0.711, Validation Accuracy:  0.679, Loss:  0.420
# Epoch   3 Batch  114/134 - Train Accuracy:  0.679, Validation Accuracy:  0.687, Loss:  0.473
# Epoch   3 Batch  115/134 - Train Accuracy:  0.667, Validation Accuracy:  0.688, Loss:  0.505
# Epoch   3 Batch  116/134 - Train Accuracy:  0.677, Validation Accuracy:  0.685, Loss:  0.481
# ...
# Epoch  18 Batch   95/134 - Train Accuracy:  0.967, Validation Accuracy:  0.968, Loss:  0.028
# Epoch  18 Batch   96/134 - Train Accuracy:  0.959, Validation Accuracy:  0.968, Loss:  0.029
# Epoch  18 Batch   97/134 - Train Accuracy:  0.963, Validation Accuracy:  0.965, Loss:  0.029
# Epoch  18 Batch   98/134 - Train Accuracy:  0.961, Validation Accuracy:  0.968, Loss:  0.031
# Epoch  18 Batch   99/134 - Train Accuracy:  0.969, Validation Accuracy:  0.965, Loss:  0.029
# Epoch  18 Batch  100/134 - Train Accuracy:  0.962, Validation Accuracy:  0.964, Loss:  0.032
# Epoch  18 Batch  101/134 - Train Accuracy:  0.962, Validation Accuracy:  0.962, Loss:  0.031
# Epoch  18 Batch  102/134 - Train Accuracy:  0.959, Validation Accuracy:  0.962, Loss:  0.029
# Epoch  18 Batch  103/134 - Train Accuracy:  0.962, Validation Accuracy:  0.962, Loss:  0.029
# Epoch  18 Batch  104/134 - Train Accuracy:  0.963, Validation Accuracy:  0.964, Loss:  0.028
# Epoch  18 Batch  105/134 - Train Accuracy:  0.959, Validation Accuracy:  0.966, Loss:  0.034
# Epoch  18 Batch  106/134 - Train Accuracy:  0.957, Validation Accuracy:  0.965, Loss:  0.030
# Epoch  18 Batch  107/134 - Train Accuracy:  0.958, Validation Accuracy:  0.962, Loss:  0.033
# Epoch  18 Batch  108/134 - Train Accuracy:  0.957, Validation Accuracy:  0.961, Loss:  0.030
# Epoch  18 Batch  109/134 - Train Accuracy:  0.967, Validation Accuracy:  0.961, Loss:  0.029
# Epoch  18 Batch  110/134 - Train Accuracy:  0.958, Validation Accuracy:  0.962, Loss:  0.030
# Epoch  18 Batch  111/134 - Train Accuracy:  0.959, Validation Accuracy:  0.964, Loss:  0.030
# Epoch  18 Batch  112/134 - Train Accuracy:  0.966, Validation Accuracy:  0.963, Loss:  0.029
# Epoch  18 Batch  113/134 - Train Accuracy:  0.963, Validation Accuracy:  0.959, Loss:  0.031
# Epoch  18 Batch  114/134 - Train Accuracy:  0.968, Validation Accuracy:  0.961, Loss:  0.029
# Epoch  18 Batch  115/134 - Train Accuracy:  0.958, Validation Accuracy:  0.965, Loss:  0.030
# Epoch  18 Batch  116/134 - Train Accuracy:  0.963, Validation Accuracy:  0.961, Loss:  0.031
# Epoch  18 Batch  117/134 - Train Accuracy:  0.967, Validation Accuracy:  0.963, Loss:  0.025
# Epoch  18 Batch  118/134 - Train Accuracy:  0.969, Validation Accuracy:  0.961, Loss:  0.029
# Epoch  18 Batch  119/134 - Train Accuracy:  0.968, Validation Accuracy:  0.959, Loss:  0.028
# Epoch  18 Batch  120/134 - Train Accuracy:  0.966, Validation Accuracy:  0.965, Loss:  0.033
# Epoch  18 Batch  121/134 - Train Accuracy:  0.956, Validation Accuracy:  0.965, Loss:  0.030
# Epoch  18 Batch  122/134 - Train Accuracy:  0.959, Validation Accuracy:  0.963, Loss:  0.032
# Epoch  18 Batch  123/134 - Train Accuracy:  0.968, Validation Accuracy:  0.962, Loss:  0.028
# Epoch  18 Batch  124/134 - Train Accuracy:  0.965, Validation Accuracy:  0.961, Loss:  0.026
# Epoch  18 Batch  125/134 - Train Accuracy:  0.969, Validation Accuracy:  0.960, Loss:  0.027
# Epoch  18 Batch  126/134 - Train Accuracy:  0.958, Validation Accuracy:  0.965, Loss:  0.031
# Epoch  18 Batch  127/134 - Train Accuracy:  0.960, Validation Accuracy:  0.964, Loss:  0.030
# Epoch  18 Batch  128/134 - Train Accuracy:  0.959, Validation Accuracy:  0.962, Loss:  0.031
# Epoch  18 Batch  129/134 - Train Accuracy:  0.965, Validation Accuracy:  0.961, Loss:  0.030
# Epoch  18 Batch  130/134 - Train Accuracy:  0.962, Validation Accuracy:  0.961, Loss:  0.030
# Epoch  18 Batch  131/134 - Train Accuracy:  0.960, Validation Accuracy:  0.963, Loss:  0.032
# Epoch  18 Batch  132/134 - Train Accuracy:  0.959, Validation Accuracy:  0.967, Loss:  0.026
# Epoch  19 Batch    0/134 - Train Accuracy:  0.966, Validation Accuracy:  0.970, Loss:  0.029
# Epoch  19 Batch    1/134 - Train Accuracy:  0.964, Validation Accuracy:  0.963, Loss:  0.030
# Epoch  19 Batch    2/134 - Train Accuracy:  0.964, Validation Accuracy:  0.957, Loss:  0.028
# Epoch  19 Batch    3/134 - Train Accuracy:  0.966, Validation Accuracy:  0.966, Loss:  0.031
# Epoch  19 Batch    4/134 - Train Accuracy:  0.960, Validation Accuracy:  0.964, Loss:  0.029
# Epoch  19 Batch    5/134 - Train Accuracy:  0.955, Validation Accuracy:  0.959, Loss:  0.034
# Epoch  19 Batch    6/134 - Train Accuracy:  0.967, Validation Accuracy:  0.961, Loss:  0.026
# Epoch  19 Batch    7/134 - Train Accuracy:  0.963, Validation Accuracy:  0.965, Loss:  0.027
# Epoch  19 Batch    8/134 - Train Accuracy:  0.965, Validation Accuracy:  0.962, Loss:  0.027
# Epoch  19 Batch    9/134 - Train Accuracy:  0.969, Validation Accuracy:  0.965, Loss:  0.025
# Epoch  19 Batch   10/134 - Train Accuracy:  0.958, Validation Accuracy:  0.965, Loss:  0.028
# Epoch  19 Batch   11/134 - Train Accuracy:  0.955, Validation Accuracy:  0.967, Loss:  0.030
# Epoch  19 Batch   12/134 - Train Accuracy:  0.962, Validation Accuracy:  0.965, Loss:  0.027
# Epoch  19 Batch   13/134 - Train Accuracy:  0.958, Validation Accuracy:  0.966, Loss:  0.028
# Epoch  19 Batch   14/134 - Train Accuracy:  0.963, Validation Accuracy:  0.969, Loss:  0.032
# Epoch  19 Batch   15/134 - Train Accuracy:  0.961, Validation Accuracy:  0.964, Loss:  0.026
# Epoch  19 Batch   16/134 - Train Accuracy:  0.963, Validation Accuracy:  0.963, Loss:  0.027
# Epoch  19 Batch   17/134 - Train Accuracy:  0.967, Validation Accuracy:  0.968, Loss:  0.032
# Epoch  19 Batch   18/134 - Train Accuracy:  0.957, Validation Accuracy:  0.963, Loss:  0.029
# Epoch  19 Batch   19/134 - Train Accuracy:  0.959, Validation Accuracy:  0.967, Loss:  0.029
# Epoch  19 Batch   20/134 - Train Accuracy:  0.964, Validation Accuracy:  0.968, Loss:  0.026
# Epoch  19 Batch   21/134 - Train Accuracy:  0.962, Validation Accuracy:  0.970, Loss:  0.029
# Epoch  19 Batch   22/134 - Train Accuracy:  0.963, Validation Accuracy:  0.971, Loss:  0.028
# Epoch  19 Batch   23/134 - Train Accuracy:  0.965, Validation Accuracy:  0.969, Loss:  0.025
# Epoch  19 Batch   24/134 - Train Accuracy:  0.962, Validation Accuracy:  0.968, Loss:  0.031
# Epoch  19 Batch   25/134 - Train Accuracy:  0.965, Validation Accuracy:  0.966, Loss:  0.025
# Epoch  19 Batch   26/134 - Train Accuracy:  0.970, Validation Accuracy:  0.967, Loss:  0.029
# Epoch  19 Batch   27/134 - Train Accuracy:  0.958, Validation Accuracy:  0.965, Loss:  0.028
# Epoch  19 Batch   28/134 - Train Accuracy:  0.961, Validation Accuracy:  0.965, Loss:  0.030
# Epoch  19 Batch   29/134 - Train Accuracy:  0.966, Validation Accuracy:  0.965, Loss:  0.024
# Epoch  19 Batch   30/134 - Train Accuracy:  0.957, Validation Accuracy:  0.970, Loss:  0.030
# Epoch  19 Batch   31/134 - Train Accuracy:  0.965, Validation Accuracy:  0.973, Loss:  0.030
# Epoch  19 Batch   32/134 - Train Accuracy:  0.966, Validation Accuracy:  0.974, Loss:  0.030
# Epoch  19 Batch   33/134 - Train Accuracy:  0.960, Validation Accuracy:  0.970, Loss:  0.033
# Epoch  19 Batch   34/134 - Train Accuracy:  0.961, Validation Accuracy:  0.969, Loss:  0.031
# Epoch  19 Batch   35/134 - Train Accuracy:  0.963, Validation Accuracy:  0.970, Loss:  0.034
# Epoch  19 Batch   36/134 - Train Accuracy:  0.965, Validation Accuracy:  0.969, Loss:  0.028
# Epoch  19 Batch   37/134 - Train Accuracy:  0.963, Validation Accuracy:  0.967, Loss:  0.031
# Epoch  19 Batch   38/134 - Train Accuracy:  0.962, Validation Accuracy:  0.966, Loss:  0.028
# Epoch  19 Batch   39/134 - Train Accuracy:  0.960, Validation Accuracy:  0.968, Loss:  0.028
# Epoch  19 Batch   40/134 - Train Accuracy:  0.967, Validation Accuracy:  0.970, Loss:  0.029
# Epoch  19 Batch   41/134 - Train Accuracy:  0.962, Validation Accuracy:  0.971, Loss:  0.034
# Epoch  19 Batch   42/134 - Train Accuracy:  0.969, Validation Accuracy:  0.969, Loss:  0.026
# Epoch  19 Batch   43/134 - Train Accuracy:  0.964, Validation Accuracy:  0.963, Loss:  0.027
# Epoch  19 Batch   44/134 - Train Accuracy:  0.965, Validation Accuracy:  0.961, Loss:  0.027
# Epoch  19 Batch   45/134 - Train Accuracy:  0.972, Validation Accuracy:  0.962, Loss:  0.026
# Epoch  19 Batch   46/134 - Train Accuracy:  0.966, Validation Accuracy:  0.969, Loss:  0.031
# Epoch  19 Batch   47/134 - Train Accuracy:  0.961, Validation Accuracy:  0.967, Loss:  0.029
# Epoch  19 Batch   48/134 - Train Accuracy:  0.963, Validation Accuracy:  0.967, Loss:  0.029
# Epoch  19 Batch   49/134 - Train Accuracy:  0.968, Validation Accuracy:  0.965, Loss:  0.028
# Epoch  19 Batch   50/134 - Train Accuracy:  0.963, Validation Accuracy:  0.967, Loss:  0.031
# Epoch  19 Batch   51/134 - Train Accuracy:  0.967, Validation Accuracy:  0.968, Loss:  0.030
# Epoch  19 Batch   52/134 - Train Accuracy:  0.968, Validation Accuracy:  0.967, Loss:  0.028
# Epoch  19 Batch   53/134 - Train Accuracy:  0.969, Validation Accuracy:  0.969, Loss:  0.028
# Epoch  19 Batch   54/134 - Train Accuracy:  0.957, Validation Accuracy:  0.970, Loss:  0.029
# Epoch  19 Batch   55/134 - Train Accuracy:  0.963, Validation Accuracy:  0.968, Loss:  0.029
# Epoch  19 Batch   56/134 - Train Accuracy:  0.957, Validation Accuracy:  0.969, Loss:  0.030
# Epoch  19 Batch   57/134 - Train Accuracy:  0.961, Validation Accuracy:  0.962, Loss:  0.029
# Epoch  19 Batch   58/134 - Train Accuracy:  0.963, Validation Accuracy:  0.964, Loss:  0.026
# Epoch  19 Batch   59/134 - Train Accuracy:  0.961, Validation Accuracy:  0.966, Loss:  0.029
# Epoch  19 Batch   60/134 - Train Accuracy:  0.965, Validation Accuracy:  0.967, Loss:  0.026
# Epoch  19 Batch   61/134 - Train Accuracy:  0.967, Validation Accuracy:  0.967, Loss:  0.027
# Epoch  19 Batch   62/134 - Train Accuracy:  0.957, Validation Accuracy:  0.964, Loss:  0.028
# Epoch  19 Batch   63/134 - Train Accuracy:  0.968, Validation Accuracy:  0.963, Loss:  0.028
# Epoch  19 Batch   64/134 - Train Accuracy:  0.959, Validation Accuracy:  0.966, Loss:  0.029
# Epoch  19 Batch   65/134 - Train Accuracy:  0.952, Validation Accuracy:  0.966, Loss:  0.030
# Epoch  19 Batch   66/134 - Train Accuracy:  0.959, Validation Accuracy:  0.967, Loss:  0.025
# Epoch  19 Batch   67/134 - Train Accuracy:  0.959, Validation Accuracy:  0.968, Loss:  0.031
# Epoch  19 Batch   68/134 - Train Accuracy:  0.960, Validation Accuracy:  0.966, Loss:  0.029
# Epoch  19 Batch   69/134 - Train Accuracy:  0.961, Validation Accuracy:  0.966, Loss:  0.027
# Epoch  19 Batch   70/134 - Train Accuracy:  0.968, Validation Accuracy:  0.968, Loss:  0.030
# Epoch  19 Batch   71/134 - Train Accuracy:  0.968, Validation Accuracy:  0.971, Loss:  0.023
# Epoch  19 Batch   72/134 - Train Accuracy:  0.960, Validation Accuracy:  0.972, Loss:  0.026
# Epoch  19 Batch   73/134 - Train Accuracy:  0.969, Validation Accuracy:  0.964, Loss:  0.032
# Epoch  19 Batch   74/134 - Train Accuracy:  0.963, Validation Accuracy:  0.959, Loss:  0.030
# Epoch  19 Batch   75/134 - Train Accuracy:  0.965, Validation Accuracy:  0.964, Loss:  0.028
# Epoch  19 Batch   76/134 - Train Accuracy:  0.970, Validation Accuracy:  0.964, Loss:  0.028
# Epoch  19 Batch   77/134 - Train Accuracy:  0.961, Validation Accuracy:  0.964, Loss:  0.027
# Epoch  19 Batch   78/134 - Train Accuracy:  0.958, Validation Accuracy:  0.966, Loss:  0.027
# Epoch  19 Batch   79/134 - Train Accuracy:  0.959, Validation Accuracy:  0.965, Loss:  0.027
# Epoch  19 Batch   80/134 - Train Accuracy:  0.968, Validation Accuracy:  0.971, Loss:  0.026
# Epoch  19 Batch   81/134 - Train Accuracy:  0.969, Validation Accuracy:  0.969, Loss:  0.027
# Epoch  19 Batch   82/134 - Train Accuracy:  0.968, Validation Accuracy:  0.969, Loss:  0.026
# Epoch  19 Batch   83/134 - Train Accuracy:  0.961, Validation Accuracy:  0.971, Loss:  0.028
# Epoch  19 Batch   84/134 - Train Accuracy:  0.950, Validation Accuracy:  0.967, Loss:  0.028
# Epoch  19 Batch   85/134 - Train Accuracy:  0.966, Validation Accuracy:  0.969, Loss:  0.030
# Epoch  19 Batch   86/134 - Train Accuracy:  0.968, Validation Accuracy:  0.972, Loss:  0.026
# Epoch  19 Batch   87/134 - Train Accuracy:  0.961, Validation Accuracy:  0.973, Loss:  0.033
# Epoch  19 Batch   88/134 - Train Accuracy:  0.968, Validation Accuracy:  0.974, Loss:  0.025
# Epoch  19 Batch   89/134 - Train Accuracy:  0.968, Validation Accuracy:  0.974, Loss:  0.027
# Epoch  19 Batch   90/134 - Train Accuracy:  0.962, Validation Accuracy:  0.970, Loss:  0.031
# Epoch  19 Batch   91/134 - Train Accuracy:  0.970, Validation Accuracy:  0.968, Loss:  0.023
# Epoch  19 Batch   92/134 - Train Accuracy:  0.969, Validation Accuracy:  0.969, Loss:  0.026
# Epoch  19 Batch   93/134 - Train Accuracy:  0.963, Validation Accuracy:  0.973, Loss:  0.025
# Epoch  19 Batch   94/134 - Train Accuracy:  0.967, Validation Accuracy:  0.974, Loss:  0.027
# Epoch  19 Batch   95/134 - Train Accuracy:  0.970, Validation Accuracy:  0.974, Loss:  0.026
# Epoch  19 Batch   96/134 - Train Accuracy:  0.961, Validation Accuracy:  0.973, Loss:  0.025
# Epoch  19 Batch   97/134 - Train Accuracy:  0.964, Validation Accuracy:  0.969, Loss:  0.027
# Epoch  19 Batch   98/134 - Train Accuracy:  0.966, Validation Accuracy:  0.971, Loss:  0.029
# Epoch  19 Batch   99/134 - Train Accuracy:  0.969, Validation Accuracy:  0.972, Loss:  0.027
# Epoch  19 Batch  100/134 - Train Accuracy:  0.965, Validation Accuracy:  0.971, Loss:  0.028
# Epoch  19 Batch  101/134 - Train Accuracy:  0.963, Validation Accuracy:  0.967, Loss:  0.029
# Epoch  19 Batch  102/134 - Train Accuracy:  0.962, Validation Accuracy:  0.968, Loss:  0.029
# Epoch  19 Batch  103/134 - Train Accuracy:  0.965, Validation Accuracy:  0.966, Loss:  0.028
# Epoch  19 Batch  104/134 - Train Accuracy:  0.965, Validation Accuracy:  0.966, Loss:  0.027
# Epoch  19 Batch  105/134 - Train Accuracy:  0.964, Validation Accuracy:  0.968, Loss:  0.032
# Epoch  19 Batch  106/134 - Train Accuracy:  0.960, Validation Accuracy:  0.968, Loss:  0.027
# Epoch  19 Batch  107/134 - Train Accuracy:  0.963, Validation Accuracy:  0.968, Loss:  0.032
# Epoch  19 Batch  108/134 - Train Accuracy:  0.962, Validation Accuracy:  0.966, Loss:  0.028
# Epoch  19 Batch  109/134 - Train Accuracy:  0.961, Validation Accuracy:  0.962, Loss:  0.027
# Epoch  19 Batch  110/134 - Train Accuracy:  0.959, Validation Accuracy:  0.965, Loss:  0.028
# Epoch  19 Batch  111/134 - Train Accuracy:  0.958, Validation Accuracy:  0.966, Loss:  0.030
# Epoch  19 Batch  112/134 - Train Accuracy:  0.965, Validation Accuracy:  0.965, Loss:  0.029
# Epoch  19 Batch  113/134 - Train Accuracy:  0.961, Validation Accuracy:  0.962, Loss:  0.031
# Epoch  19 Batch  114/134 - Train Accuracy:  0.965, Validation Accuracy:  0.964, Loss:  0.027
# Epoch  19 Batch  115/134 - Train Accuracy:  0.957, Validation Accuracy:  0.963, Loss:  0.028
# Epoch  19 Batch  116/134 - Train Accuracy:  0.965, Validation Accuracy:  0.963, Loss:  0.031
# Epoch  19 Batch  117/134 - Train Accuracy:  0.973, Validation Accuracy:  0.963, Loss:  0.023
# Epoch  19 Batch  118/134 - Train Accuracy:  0.965, Validation Accuracy:  0.958, Loss:  0.026
# Epoch  19 Batch  119/134 - Train Accuracy:  0.971, Validation Accuracy:  0.960, Loss:  0.026
# Epoch  19 Batch  120/134 - Train Accuracy:  0.966, Validation Accuracy:  0.965, Loss:  0.031
# Epoch  19 Batch  121/134 - Train Accuracy:  0.952, Validation Accuracy:  0.960, Loss:  0.026
# Epoch  19 Batch  122/134 - Train Accuracy:  0.958, Validation Accuracy:  0.966, Loss:  0.029
# Epoch  19 Batch  123/134 - Train Accuracy:  0.965, Validation Accuracy:  0.965, Loss:  0.026
# Epoch  19 Batch  124/134 - Train Accuracy:  0.962, Validation Accuracy:  0.961, Loss:  0.024
# Epoch  19 Batch  125/134 - Train Accuracy:  0.967, Validation Accuracy:  0.965, Loss:  0.025
# Epoch  19 Batch  126/134 - Train Accuracy:  0.960, Validation Accuracy:  0.966, Loss:  0.026
# Epoch  19 Batch  127/134 - Train Accuracy:  0.961, Validation Accuracy:  0.962, Loss:  0.026
# Epoch  19 Batch  128/134 - Train Accuracy:  0.959, Validation Accuracy:  0.963, Loss:  0.032
# Epoch  19 Batch  129/134 - Train Accuracy:  0.963, Validation Accuracy:  0.963, Loss:  0.030
# Epoch  19 Batch  130/134 - Train Accuracy:  0.965, Validation Accuracy:  0.965, Loss:  0.030
# Epoch  19 Batch  131/134 - Train Accuracy:  0.960, Validation Accuracy:  0.966, Loss:  0.029
# Epoch  19 Batch  132/134 - Train Accuracy:  0.959, Validation Accuracy:  0.969, Loss:  0.025
# Model Trained and Saved

# %% [markdown]
# ### Save Parameters
# Save the `batch_size` and `save_path` parameters for inference.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# Save parameters for checkpoint
helper.save_params(save_path)

# %% [markdown]
# # Checkpoint

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import tensorflow as tf
import numpy as np
import helper
import problem_unittests as tests

_, (source_vocab_to_int, target_vocab_to_int), (source_int_to_vocab, target_int_to_vocab) = helper.load_preprocess()
load_path = helper.load_params()

# %% [markdown]
# ## Sentence to Sequence
# To feed a sentence into the model for translation, you first need to preprocess it.  Implement the function `sentence_to_seq()` to preprocess new sentences.
#
# - Convert the sentence to lowercase
# - Convert words into ids using `vocab_to_int`
#  - Convert words not in the vocabulary, to the `<UNK>` word id.

# %%
def sentence_to_seq(sentence, vocab_to_int):
    """
    Convert a sentence to a sequence of ids
    :param sentence: String
    :param vocab_to_int: Dictionary to go from the words to an id
    :return: List of word ids
    """
    
    words = sentence.split()
    words = [word.lower() for word in words]
    ids = [vocab_to_int[word] if word in vocab_to_int else vocab_to_int['<UNK>'] for word in words]

    return ids


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_sentence_to_seq(sentence_to_seq)
# Out:
# Tests Passed

# %% [markdown]
# ## Translate
# This will translate `translate_sentence` from English to French.

# %%
#translate_sentence = 'he saw a old yellow truck .'
translate_sentence = 'his least favorite animal is the mouse .'



"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
translate_sentence = sentence_to_seq(translate_sentence, source_vocab_to_int)

loaded_graph = tf.Graph()
with tf.Session(graph=loaded_graph) as sess:
    # Load saved model
    loader = tf.train.import_meta_graph(load_path + '.meta')
    loader.restore(sess, load_path)

    input_data = loaded_graph.get_tensor_by_name('input:0')
    logits = loaded_graph.get_tensor_by_name('logits:0')
    keep_prob = loaded_graph.get_tensor_by_name('keep_prob:0')

    translate_logits = sess.run(logits, {input_data: [translate_sentence], keep_prob: 1.0})[0]

print('Input')
print('  Word Ids:      {}'.format([i for i in translate_sentence]))
print('  English Words: {}'.format([source_int_to_vocab[i] for i in translate_sentence]))

print('\nPrediction')
print('  Word Ids:      {}'.format([i for i in np.argmax(translate_logits, 1)]))
print('  French Words: {}'.format([target_int_to_vocab[i] for i in np.argmax(translate_logits, 1)]))
# Out:
# Input
#   Word Ids:      [65, 149, 221, 61, 135, 189, 33, 79]
#   English Words: ['his', 'least', 'favorite', 'animal', 'is', 'the', 'mouse', '.']
#
# Prediction
#   Word Ids:      [140, 190, 92, 307, 331, 74, 209, 1]
#   French Words: ['son', 'fruit', 'préféré', 'est', 'moins', "l'orange", '.', '<EOS>']

# %% [markdown]
# ## Imperfect Translation
# You might notice that some sentences translate better than others.  Since the dataset you're using only has a vocabulary of 227 English words of the thousands that you use, you're only going to see good results using these words.  For this project, you don't need a perfect translation. However, if you want to create a better translation model, you'll need better data.
#
# You can train on the [WMT10 French-English corpus](http://www.statmt.org/wmt10/training-giga-fren.tar).  This dataset has more vocabulary and richer in topics discussed.  However, this will take you days to train, so make sure you've a GPU and the neural network is performing well on dataset we provided.  Just make sure you play with the WMT10 corpus after you've submitted this project.
# ## Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook. Save the notebook file as "dlnd_language_translation.ipynb" and save it as a HTML file under "File" -> "Download as". Include the "helper.py" and "problem_unittests.py" files in your submission.
